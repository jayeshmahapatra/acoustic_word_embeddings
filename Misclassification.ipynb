# %% [markdown]
# # Notebook to Visualize Misclassifications

# %% [markdown]
# ## 1. Import Libraries

# %%
#Core Python, Pandas, and kaldi_io
import numpy as np
import pandas as pd
import string
from collections import Counter
import random
import kaldi_io

#Scikit
from sklearn import manifold
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import pairwise_distances,average_precision_score
from sklearn.metrics.pairwise import pairwise_kernels
from scipy import stats
from scipy.spatial.distance import pdist
from scipy.stats import kurtosis
from scipy.stats import skew

#Plotting
from matplotlib import pyplot as plt
import seaborn as sns



#Torch and utilities
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset,DataLoader,random_split,ConcatDataset
import torch.cuda as cutorch

#Import User defined classes
from data_helpers import DataHelper
from models import SimpleNet, SimpleNet_with_dropout, SiameseNet
from train_test_helpers import evaluate_model,test_model, baseline, accuracy
from datasets import CNN_dataset, SiameseTriplets
# Out:
# ################################################################################
# ### WARNING, path does not exist: KALDI_ROOT=/mnt/matylda5/iveselyk/Tools/kaldi-trunk
# ###          (please add 'export KALDI_ROOT=<your_path>' in your $HOME/.profile)
# ###          (or run as: KALDI_ROOT=<your_path> python <your_script>.py)
# ################################################################################

# %% [markdown]
# ## 2. Data Loading and Common Functions

# %%
clean_ds = CNN_dataset(split_set = "test", char_threshold = 5, frequency_bounds = (0,np.Inf), snr = np.Inf, k = np.Inf, cluster = False)
# Out:
# Length before filtering on char length 169383
# Length after filtering on char length 80821
# Finished Loading the Data, 80821 examples
# Number of Unique words  8607
# Length before filtering on frequency_bounds  (80821,)
# Not filtering
# (48492, 40, 100) (16164, 40, 100) (16165, 40, 100)

# %%
clean_num_to_word, clean_word_to_num = clean_ds.num_to_word.copy(),clean_ds.word_to_num.copy()
del clean_ds

# %%
dev = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
def clean_mapping(yb):
    mapped_yb = [clean_word_to_num[test_ds.num_to_word[yb[i].item()]] for i in range(yb.shape[0])]
    mapped_yb = torch.tensor(mapped_yb)
    
    return mapped_yb

# %%
def load_test(snr = np.Inf):
    '''Function to load test data of a given snr'''
    bs = 64
    #Test Dataset
    test_ds = CNN_dataset(split_set = "test", char_threshold = 5, frequency_bounds = (0,np.Inf), snr = snr, k = np.Inf, cluster = False)
    #Dataloaders
    test_dl = DataLoader(test_ds, batch_size=bs, pin_memory = True, shuffle = True, drop_last = True)
    
    print(len(test_ds.num_to_word.keys()),len(clean_num_to_word))
    print(test_ds.num_to_word == clean_num_to_word)
    
    return test_ds,test_dl

# %%
def load_model(num_output):
    '''Function to create a model given number of outputs, and load weights'''
    
    num_output = len(clean_num_to_word.keys())
    #CNN
    net = SimpleNet(num_output)
    net = net.float()
    net.to(dev)
    
    model_save_path = "Models/cnn_clean.pth"
    #Load model weights
    net.load_state_dict(torch.load(model_save_path))
    
    return net

# %%
def predict_on_test(net, test_dl):
    '''Function to predict on a given test set'''
    word_to_pred = {}
    test_acc = 0
    y_pred_labels = None
    for xb,yb in test_dl:
        #Transform yb to clean mappings
        yb = clean_mapping(yb)

        #Move to GPU
        xb,yb = xb.to(dev, non_blocking=True),yb.to(dev, non_blocking=True)
        y_pred = net(xb)

        test_acc += accuracy(y_pred,yb.long())
        
        #Add it to y_pred_with_labels
        if y_pred_labels is None:
            y_pred_labels = np.concatenate((yb.cpu().detach().numpy().reshape(-1,1),y_pred.cpu().detach().numpy()), axis = 1)
        else:
            curr_y_pred_labels = np.concatenate((yb.cpu().detach().numpy().reshape(-1,1),y_pred.cpu().detach().numpy()), axis = 1)
            y_pred_labels = np.concatenate((y_pred_labels, curr_y_pred_labels))
        


        for i in range(y_pred.shape[0]):
            word = clean_num_to_word[yb[i].item()]
            pred = clean_num_to_word[torch.argmax(y_pred[i]).item()]

            if word in word_to_pred.keys():
                word_to_pred[word].append(pred)
            else:
                word_to_pred[word] = [pred]

    test_acc = test_acc/len(test_dl)

    print("Test Accuracy ", test_acc.item())
    
    return word_to_pred, y_pred_labels

# %% [markdown]
# ## 3. Prediction

# %%
#Load Best Clean Model
num_output = len(clean_num_to_word.keys()) #Num output is same as clean dataset
net = load_model(num_output)

# %%
snr_values = [np.Inf, 20, 5, 0 , -5]

for snr in snr_values:
    #Load test data
    test_ds,test_dl = load_test(snr = snr)
    #predict on test data
    word_to_pred, y_pred_labels = predict_on_test(net, test_dl)
    
    #Save word_to_pred and y_pred
    
    if snr < np.Inf:
        np.save('Data/snr%d_word_to_pred.npy'%(snr), word_to_pred)
        np.save('Data/snr%d_y_pred_labels.npy'%(snr), y_pred_labels)
    else:
        np.save('Data/clean_word_to_pred.npy', word_to_pred)
        np.save('Data/clean_y_pred_labels.npy', y_pred_labels)
    
    del word_to_pred, y_pred_labels, test_ds,test_dl
# Out:
# Length before filtering on char length 169383
# Length after filtering on char length 80821
# Finished Loading the Data, 80821 examples
# Number of Unique words  8607
# Length before filtering on frequency_bounds  (80821,)
# Not filtering
# (48492, 40, 100) (16164, 40, 100) (16165, 40, 100)
# 8607 8607
# True
# Test Accuracy  0.3509424924850464
# Length before filtering on char length 169343
# Length after filtering on char length 80810
# Finished Loading the Data, 80810 examples
# Number of Unique words  8606
# Length before filtering on frequency_bounds  (80810,)
# Not filtering
# (48486, 40, 100) (16162, 40, 100) (16162, 40, 100)
# 8606 8607
# False
# Test Accuracy  0.2113715410232544
# Length before filtering on char length 169299
# Length after filtering on char length 80781
# Finished Loading the Data, 80781 examples
# Number of Unique words  8606
# Length before filtering on frequency_bounds  (80781,)
# Not filtering
# (48468, 40, 100) (16156, 40, 100) (16157, 40, 100)
# 8606 8607
# False
# Test Accuracy  0.01289682649075985
# Length before filtering on char length 169315
# Length after filtering on char length 80791
# Finished Loading the Data, 80791 examples
# Number of Unique words  8607
# Length before filtering on frequency_bounds  (80791,)
# Not filtering
# (48474, 40, 100) (16158, 40, 100) (16159, 40, 100)
# 8607 8607
# False
# Test Accuracy  0.006448413245379925
# Length before filtering on char length 169370
# Length after filtering on char length 80813
# Finished Loading the Data, 80813 examples
# Number of Unique words  8607
# Length before filtering on frequency_bounds  (80813,)
# Not filtering
# (48487, 40, 100) (16163, 40, 100) (16163, 40, 100)
# 8607 8607
# True
# Test Accuracy  0.004092262126505375

# %% [markdown]
# ## 4. Visualization

# %%
from sfba4.utils import alignSequences

# %%
#Load the word phoneme dict
word_phoneme_dict = np.load("Data/word_phoneme_dict.npy", allow_pickle = True).item()

# %%
word_phoneme_dict
# Out:
# {'pixel': 'P IH K S AH L',
#  'finds': 'F AY N D Z',
#  'echelons': 'EH SH AH L AA N Z',
#  'suppo': 'S UW P OW',
#  'brick': 'B R IH K',
#  'smallish': 'S M AO L IH SH',
#  'execute': 'EH K S AH K Y UW T',
#  'ignore': 'IH G N AO R',
#  'doesnt': 'D OW S AH N T',
#  'injury': 'IH N JH ER IY',
#  'lowering': 'L OW ER IH NG',
#  'innova': 'IH N OW V AH',
#  'horses': 'HH AO R S AH Z',
#  'atmosphere': 'AE T M AH S F IH R',
#  'kangaroo': 'K AE NG G ER UW',
#  'preparing': 'P R IY P EH R IH NG',
#  'refining': 'R AH F AY N IH NG',
#  'hypothetically': 'HH AY P AH TH EH T IH K L IY',
#  'beams': 'B IY M Z',
#  'sucking': 'S AH K IH NG',
#  'arbitrarily': 'AA R B IH T R EH R AH L IY',
#  'teambuilding': 'T IY M B IH L D IH NG',
#  'semisuperv': 'S EH M IY S UW P ER V',
#  'lefthander': 'L EH F T HH AE N D ER',
#  'assignments': 'AH S AY N M AH N T S',
#  'script': 'S K R IH P T',
#  'decision': 'D IH S IH ZH AH N',
#  'candidates': 'K AE N D AH D EY T S',
#  'fruitful': 'F R UW T F AH L',
#  'redundancy': 'R IH D AH N D AH N S IY',
#  'conformable': 'K AH N F AO R M AH B AH L',
#  'scroll': 'S K R OW L',
#  'menudriven': 'M EH N AH D R AY V AH N',
#  'pronounce': 'P R AH N AW N S',
#  'siemens': 'S IY M AH N Z',
#  'seasons': 'S IY Z AH N Z',
#  'synched': 'S IH N CH T',
#  'bloody': 'B L AH D IY',
#  'manufactured': 'M AE N Y AH F AE K CH ER D',
#  'tough': 'T AH F',
#  'identity': 'AY D EH N T AH T IY',
#  'adhere': 'AH D HH IH R',
#  'strangely': 'S T R EY N JH L IY',
#  'jeanneoui': 'ZH AA N IY UW IY',
#  'transistors': 'T R AE N Z IH S T ER Z',
#  'overheads': 'OW V ER HH EH D Z',
#  'deformed': 'D IH F AO R M D',
#  'allows': 'AH L AW Z',
#  'barbara': 'B AA R B ER AH',
#  'putting': 'P AH T IH NG',
#  'microstructure': 'M AY K R OW S T R AH K CH ER',
#  'interact': 'IH N T ER AE K T',
#  'slimmer': 'S L IH M ER',
#  'rotation': 'R OW T EY SH AH N',
#  'strips': 'S T R IH P S',
#  'cancel': 'K AE N S AH L',
#  'pared': 'P EH R D',
#  'leftdoubleclick': 'L EH F T D UW B L EH K L IH K',
#  'inspired': 'IH N S P AY ER D',
#  'spring': 'S P R IH NG',
#  'menus': 'M EH N Y UW Z',
#  'streamed': 'S T R IY M D',
#  'swimming': 'S W IH M IH NG',
#  'jordan': 'JH AO R D AH N',
#  'level': 'L EH V AH L',
#  'scripts': 'S K R IH P T S',
#  'raising': 'R EY Z IH NG',
#  'flops': 'F L AA P S',
#  'technologys': 'T EH K N AA L AH JH IY Z',
#  'amend': 'AH M EH N D',
#  'wheel': 'W IY L',
#  'switches': 'S W IH CH AH Z',
#  'relations': 'R IY L EY SH AH N Z',
#  'summarising': 'S AH M ER AY Z IH NG',
#  'congratulate': 'K AH N G R AE CH AH L EY T',
#  'stoplist': 'S T AA P L IH S T',
#  'prefilter': 'P R IY F IH L T ER',
#  'enhance': 'EH N HH AE N S',
#  'myself': 'M AY S EH L F',
#  'personalising': 'P ER S AA N AH L AY Z IH NG',
#  'niches': 'N IH SH IH Z',
#  'endurable': 'IH N D UH R AH B AH L',
#  'musthaves': 'M AH S T AH V Z',
#  'structural': 'S T R AH K CH ER AH L',
#  'relative': 'R EH L AH T IH V',
#  'clearcut': 'K L IH R K AH T',
#  'spider': 'S P AY D ER',
#  'brilliance': 'B R IH L Y AH N S',
#  'intent': 'IH N T EH N T',
#  'loyal': 'L OY AH L',
#  'previous': 'P R IY V IY AH S',
#  'brownie': 'B R AW N IY',
#  'leopard': 'L EH P ER D',
#  'martin': 'M AA R T AH N',
#  'contr': 'K AA N T ER',
#  'prevented': 'P R IH V EH N T IH D',
#  'badger': 'B AE JH ER',
#  'emitting': 'IH M IH T IH NG',
#  'forming': 'F AO R M IH NG',
#  'demanding': 'D IH M AE N D IH NG',
#  'realign': 'R IY AH L AY N',
#  'thats': 'TH AE T S',
#  'pairs': 'P EH R Z',
#  'navigate': 'N AE V AH G EY T',
#  'ionization': 'AY AH N AH Z EY SH AH N',
#  'outer': 'AW T ER',
#  'floating': 'F L OW T IH NG',
#  'urine': 'Y ER AH N',
#  'dedicate': 'D EH D AH K EY T',
#  'collapse': 'K AH L AE P S',
#  'events': 'IH V EH N T S',
#  'smart': 'S M AA R T',
#  'explained': 'IH K S P L EY N D',
#  'undercut': 'AH N D ER K AH T',
#  'presented': 'P R IY Z EH N T AH D',
#  'stored': 'S T AO R D',
#  'pictures': 'P IH K CH ER Z',
#  'keyword': 'K IY W ER D',
#  'priorities': 'P R AY AO R AH T IY Z',
#  'volumedown': 'V AH L UW M D AW N',
#  'vendors': 'V EH N D ER Z',
#  'reads': 'R IY D Z',
#  'conversation': 'K AA N V ER S EY SH AH N',
#  'connects': 'K AH N EH K T S',
#  'pasting': 'P EY S T IH NG',
#  'purdy': 'P ER D IY',
#  'democratically': 'D EH M AH K R AE T IH K L IY',
#  'press': 'P R EH S',
#  'booming': 'B UW M IH NG',
#  'massive': 'M AE S IH V',
#  'kates': 'K EY T S',
#  'corrine': 'K ER IY N',
#  'passionate': 'P AE SH AH N AH T',
#  'totally': 'T OW T AH L IY',
#  'timestamped': 'T AY M S T AE M P T',
#  'referring': 'R IH F ER IH NG',
#  'nonrecta': 'N AA N R EH K T AH',
#  'engines': 'EH N JH AH N Z',
#  'fixable': 'F IH K S AH B AH L',
#  'widely': 'W AY D L IY',
#  'happen': 'HH AE P AH N',
#  'antigoing': 'AE N T IY G OW IH NG',
#  'discover': 'D IH S K AH V ER',
#  'deconstructed': 'D IY K AH N S T R AH K T IH D',
#  'leeway': 'L IY W EY',
#  'kitchenware': 'K IH CH AH N W EH R',
#  'object': 'AA B JH EH K T',
#  'selfintersections': 'S EH L F IH N T ER S EH K SH AH N Z',
#  'juice': 'JH UW S',
#  'twohanded': 'T UW AH HH AE N D IH D',
#  'coordination': 'K OW AO R D AH N EY SH AH N',
#  'motto': 'M AA T OW',
#  'climb': 'K L AY M',
#  'interme': 'IH N T ER M',
#  'focusing': 'F OW K AH S IH NG',
#  'holiday': 'HH AA L AH D EY',
#  'finance': 'F AH N AE N S',
#  'remarkably': 'R IH M AA R K AH B L IY',
#  'monotonous': 'M AH N AA T AH N AH S',
#  'discs': 'D IH S K S',
#  'versa': 'V ER S AH',
#  'fluffy': 'F L AH F IY',
#  'attaching': 'AH T AE CH IH NG',
#  'unless': 'AH N L EH S',
#  'blurbs': 'B L ER B Z',
#  'temporary': 'T EH M P ER EH R IY',
#  'instinctual': 'IH N S T IH NG K CH UW AH L',
#  'bulge': 'B AH L JH',
#  'statue': 'S T AE CH UW',
#  'feasibility': 'F IY Z AH B IH L AH T IY',
#  'fighting': 'F AY T IH NG',
#  'wadadadadada': 'W AA D AH D AH D AA D AH D AH',
#  'arise': 'ER AY Z',
#  'buttonsll': 'B AH T AH N S AH L',
#  'righto': 'R AY T OW',
#  'useable': 'Y UW Z AH B AH L',
#  'telephone': 'T EH L AH F OW N',
#  'avoiding': 'AH V OY D IH NG',
#  'pixels': 'P IH K S AH L Z',
#  'veronica': 'V ER AA N IH K AH',
#  'elans': 'EH L AH N Z',
#  'royal': 'R OY AH L',
#  'trendiest': 'T R EH N D IY S T',
#  'symmet': 'S IH M AH T',
#  'slickness': 'S L IH K N AH S',
#  'locators': 'L OW K EY T ER Z',
#  'toolbar': 'T UW L B AA R',
#  'thousands': 'TH AW Z AH N D Z',
#  'dicier': 'D AY S IY ER',
#  'attacking': 'AH T AE K IH NG',
#  'submitting': 'S AH B M IH T IH NG',
#  'funkylooking': 'F AH NG K IY L UH K IH NG',
#  'grass': 'G R AE S',
#  'control': 'K AH N T R OW L',
#  'curvatures': 'K ER V AH CH ER Z',
#  'subgroup': 'S AH B G R UW P',
#  'unclear': 'AH N K L IH R',
#  'becomes': 'B IH K AH M Z',
#  'ending': 'EH N D IH NG',
#  'searching': 'S ER CH IH NG',
#  'embossing': 'EH M B AO S IH NG',
#  'reparable': 'R IY P EH R AH B AH L',
#  'repeated': 'R IH P IY T IH D',
#  'infor': 'IH N F ER',
#  'investigation': 'IH N V EH S T AH G EY SH AH N',
#  'higher': 'HH AY ER',
#  'progressed': 'P R AH G R EH S T',
#  'definition': 'D EH F AH N IH SH AH N',
#  'normal': 'N AO R M AH L',
#  'jokes': 'JH OW K S',
#  'hopefu': 'HH OW P IY F UW',
#  'appara': 'AA P AA R AH',
#  'evolve': 'IH V AA L V',
#  'refocus': 'R IY F OW K AH S',
#  'rever': 'R EH V ER',
#  'inventing': 'IH N V EH N T IH NG',
#  'access': 'AE K S EH S',
#  'fastforward': 'F AE S T F AO R W ER D',
#  'varying': 'V EH R IY IH NG',
#  'documentations': 'D AA K Y AH M EH N T EY SH AH N Z',
#  'silver': 'S IH L V ER',
#  'fruit': 'F R UW T',
#  'guillermo': 'G W IH L Y EH R M OW',
#  'lossiness': 'L AO S IY N AH S',
#  'emphasis': 'EH M F AH S IH S',
#  'somewhere': 'S AH M W EH R',
#  'radiowaves': 'R EY D IY OW W EY V Z',
#  'unaware': 'AH N AH W EH R',
#  'conceptual': 'K AH N S EH P CH UW AH L',
#  'reasonable': 'R IY Z AH N AH B AH L',
#  'rubble': 'R AH B AH L',
#  'nuclear': 'N UW K L IY ER',
#  'stutter': 'S T AH T ER',
#  'cushions': 'K UH SH AH N Z',
#  'changers': 'CH EY N JH ER Z',
#  'beefy': 'B IY F IY',
#  'focus': 'F OW K AH S',
#  'generat': 'JH EH N ER AH T',
#  'feasibly': 'F IY Z AH B L IY',
#  'homework': 'HH OW M W ER K',
#  'profiting': 'P R AA F AH T IH NG',
#  'manipulation': 'M AH N IH P Y AH L EY SH AH N',
#  'adult': 'AH D AH L T',
#  'judgment': 'JH AH JH M AH N T',
#  'inconsistency': 'IH N K AH N S IH S T AH N S IY',
#  'feedback': 'F IY D B AE K',
#  'handles': 'HH AE N D AH L Z',
#  'greyblack': 'G R EY B L AE K',
#  'finalising': 'F AY N AH L AY Z IH NG',
#  'additionally': 'AH D IH SH AH N AH L IY',
#  'public': 'P AH B L IH K',
#  'dissatisfy': 'D IH S AE T AH S F AY',
#  'spammed': 'S P AE M D',
#  'drape': 'D R EY P',
#  'clare': 'K L EH R',
#  'popularity': 'P AA P Y AH L EH R AH T IY',
#  'address': 'AE D R EH S',
#  'rubberness': 'R AH B ER N AH S',
#  'morning': 'M AO R N IH NG',
#  'omission': 'OW M IH SH AH N',
#  'array': 'ER EY',
#  'customized': 'K AH S T AH M AY Z D',
#  'epinions': 'IH P IH N Y AH N Z',
#  'spread': 'S P R EH D',
#  'thirteen': 'TH ER T IY N',
#  'consistent': 'K AH N S IH S T AH N T',
#  'respond': 'R IH S P AA N D',
#  'distress': 'D IH S T R EH S',
#  'compliments': 'K AA M P L AH M EH N T S',
#  'oscillating': 'AA S AH L EY T IH NG',
#  'hangup': 'HH AE NG G AH P',
#  'depression': 'D IH P R EH SH AH N',
#  'pullout': 'P UH L AW T',
#  'amplifier': 'AE M P L AH F AY ER',
#  'sector': 'S EH K T ER',
#  'selects': 'S AH L EH K T S',
#  'storyboard': 'S T AO R IY B AO R D',
#  'write': 'R AY T',
#  'discu': 'D IH S K Y UW',
#  'powerwise': 'P AW ER W AY Z',
#  'animals': 'AE N AH M AH L Z',
#  'augment': 'AO G M EH N T',
#  'receptor': 'R IY S EH P T ER',
#  'efficiency': 'IH F IH SH AH N S IY',
#  'store': 'S T AO R',
#  'wheat': 'W IY T',
#  'remultific': 'R IY M AH L T IH F IH K',
#  'summary': 'S AH M ER IY',
#  'microphone': 'M AY K R AH F OW N',
#  'whens': 'W IH N Z',
#  'cordless': 'K AO R D L AH S',
#  'encouraged': 'EH N K ER IH JH D',
#  'fitted': 'F IH T AH D',
#  'inverse': 'IH N V ER S',
#  'pricing': 'P R AY S IH NG',
#  'mediumlow': 'M IY D IY AH M L OW',
#  'leaderships': 'L IY D ER SH IH P S',
#  'screwed': 'S K R UW D',
#  'checking': 'CH EH K IH NG',
#  'blunt': 'B L AH N T',
#  'algorithmic': 'AE L G ER IH TH M IH K',
#  'phrases': 'F R EY Z AH Z',
#  'dryread': 'D R AY R EH D',
#  'prefer': 'P R AH F ER',
#  'bucciantini': 'B UW CH AH N T IY N IY',
#  'regret': 'R AH G R EH T',
#  'memory': 'M EH M ER IY',
#  'appliances': 'AH P L AY AH N S IH Z',
#  'disfluenc': 'D IH S F L UW AH NG K',
#  'concatenating': 'K AH N K AE T AH N EY T IH NG',
#  'hinge': 'HH IH N JH',
#  'blank': 'B L AE NG K',
#  'basics': 'B EY S IH K S',
#  'galactic': 'G AH L AE K T IH K',
#  'freedom': 'F R IY D AH M',
#  'piece': 'P IY S',
#  'complementary': 'K AA M P L AH M EH N T R IY',
#  'disappeared': 'D IH S AH P IH R D',
#  'smiles': 'S M AY L Z',
#  'extraction': 'EH K S T R AE K SH AH N',
#  'following': 'F AA L OW IH NG',
#  'subcentrally': 'S AH B S EH N T R AH L IY',
#  'inspect': 'IH N S P EH K T',
#  'pinpoint': 'P IH N P OY N T',
#  'directories': 'D AY R EH K T ER IY Z',
#  'lives': 'L IH V Z',
#  'smash': 'S M AE SH',
#  'companys': 'K AH M P AH N IY Z',
#  'prese': 'P R IY Z',
#  'verbal': 'V ER B AH L',
#  'yourself': 'Y ER S EH L F',
#  'rotsym': 'R AA T S IH M',
#  'calculation': 'K AE L K Y AH L EY SH AH N',
#  'applications': 'AE P L AH K EY SH AH N Z',
#  'television': 'T EH L AH V IH ZH AH N',
#  'ugliness': 'AH G L IY N AH S',
#  'vertical': 'V ER T IH K AH L',
#  'offer': 'AO F ER',
#  'grief': 'G R IY F',
#  'unmanageable': 'AH N M AE N IH JH AH B AH L',
#  'actors': 'AE K T ER Z',
#  'smallville': 'S M AO L V IH L',
#  'industrati': 'IH N D UW S T R AA T IY',
#  'saturation': 'S AE CH ER EY SH AH N',
#  'ontologies': 'AA N T AA L AH JH IY Z',
#  'corner': 'K AO R N ER',
#  'accentuate': 'AE K S EH N CH UW EY T',
#  'exactly': 'IH G Z AE K T L IY',
#  'maarika': 'M AA ER IY K AH',
#  'challenged': 'CH AE L AH N JH D',
#  'midjanuary': 'M IH D JH AE N Y UW EH R IY',
#  'signal': 'S IH G N AH L',
#  'diversity': 'D IH V ER S IH T IY',
#  'boxes': 'B AA K S AH Z',
#  'seminar': 'S EH M AH N AA R',
#  'motivation': 'M OW T AH V EY SH AH N',
#  'flaunt': 'F L AO N T',
#  'ionizing': 'AY AH N AY Z IH NG',
#  'durable': 'D UH R AH B AH L',
#  'incorporates': 'IH N K AO R P ER EY T S',
#  'plays': 'P L EY Z',
#  'initiation': 'IH N IH SH IY EY SH AH N',
#  'tones': 'T OW N Z',
#  'harvard': 'HH AA R V ER D',
#  'necess': 'N IY S EH S',
#  'release': 'R IY L IY S',
#  'michigan': 'M IH SH IH G AH N',
#  'listen': 'L IH S AH N',
#  'bizarre': 'B AH Z AA R',
#  'receiv': 'R IH S IY V',
#  'criterion': 'K R AY T IH R IY AH N',
#  'vertically': 'V ER T IH K L IY',
#  'rectangular': 'R EH K T AE NG G Y AH L ER',
#  'changes': 'CH EY N JH AH Z',
#  'preferably': 'P R EH F ER AH B L IY',
#  'forever': 'F ER EH V ER',
#  'utterance': 'AH T ER AH N S',
#  'emphasising': 'EH M F AH S AY Z IH NG',
#  'provin': 'P R OW V IH N',
#  'distributor': 'D IH S T R IH B Y AH T ER',
#  'inverted': 'IH N V ER T IH D',
#  'documents': 'D AA K Y AH M AH N T S',
#  'thicker': 'TH IH K ER',
#  'plugs': 'P L AH G Z',
#  'falafel': 'F AH L AA F AH L',
#  'negation': 'N AH G EY SH AH N',
#  'passage': 'P AE S AH JH',
#  'working': 'W ER K IH NG',
#  'eastpack': 'IY S T P AE K',
#  'fetching': 'F EH CH IH NG',
#  'elongated': 'IH L AO NG G EY T AH D',
#  'engineered': 'EH N JH AH N IY R D',
#  'selected': 'S AH L EH K T AH D',
#  'successfully': 'S AH K S EH S F AH L IY',
#  'lightings': 'L AY T IH NG Z',
#  'leaner': 'L IY N ER',
#  'rounder': 'R AW N D ER',
#  'frightening': 'F R AY T AH N IH NG',
#  'clearer': 'K L IH R ER',
#  'correctly': 'K ER EH K T L IY',
#  'translates': 'T R AE N Z L EY T S',
#  'niels': 'N IY L Z',
#  'literature': 'L IH T ER AH CH ER',
#  'righthand': 'R AY T HH AE N D',
#  'amuse': 'AH M Y UW Z',
#  'singlecurve': 'S IH NG G AH L K ER V',
#  'clobber': 'K L AA B ER',
#  'cleans': 'K L IY N Z',
#  'warned': 'W AO R N D',
#  'ideals': 'AY D IY L Z',
#  'offerings': 'AO F ER IH NG Z',
#  'minima': 'M IH N IY M AH',
#  'findings': 'F AY N D IH NG Z',
#  'whatev': 'W AH T EH V',
#  'prohibitive': 'P R OW HH IH B AH T IH V',
#  'physiotherapy': 'F IH Z IY OW TH EH R AH P IY',
#  'conception': 'K AH N S EH P SH AH N',
#  'directed': 'D ER EH K T AH D',
#  'representational': 'R EH P R AH Z AH N T EY SH AH N AH L',
#  'gaudy': 'G AO D IY',
#  'onedimensional': 'AA N AH D IH M EH N SH AH N AH L',
#  'weaker': 'W IY K ER',
#  'cycling': 'S AY K AH L IH NG',
#  'driven': 'D R IH V AH N',
#  'beautifully': 'B Y UW T AH F L IY',
#  'discommunicate': 'D IH S K AH M Y UW N AH K EY T',
#  'onehanded': 'AA N IH HH AE N D IH D',
#  'chitchat': 'CH IH T CH AE T',
#  'lithium': 'L IH TH IY AH M',
#  'mightve': 'M AY T V',
#  'desires': 'D IH Z AY ER Z',
#  'drunk': 'D R AH NG K',
#  'dynamic': 'D AY N AE M IH K',
#  'concrete': 'K AH N K R IY T',
#  'returns': 'R IH T ER N Z',
#  'superficial': 'S UW P ER F IH SH AH L',
#  'whisper': 'W IH S P ER',
#  'capitals': 'K AE P AH T AH L Z',
#  'selfintersection': 'S EH L F IH N T ER S EH K SH AH N',
#  'gimmicks': 'G IH M IH K S',
#  'million': 'M IH L Y AH N',
#  'compare': 'K AH M P EH R',
#  'graph': 'G R AE F',
#  'drawing': 'D R AO IH NG',
#  'expect': 'IH K S P EH K T',
#  'bathgate': 'B AE TH G EY T',
#  'recon': 'R IY K AO N',
#  'straightout': 'S T R EY T AW T',
#  'distraction': 'D IH S T R AE K SH AH N',
#  'carrier': 'K AE R IY ER',
#  'densities': 'D EH N S AH T IY Z',
#  'geometrical': 'JH IY AH M EH T R IH K AH L',
#  'touchscreen': 'T AH CH S K R IY N',
#  'dampers': 'D AE M P ER Z',
#  'telcon': 'T EH L K AH N',
#  'giraffe': 'JH ER AE F',
#  'demographic': 'D EH M AH G R AE F IH K',
#  'soccer': 'S AA K ER',
#  'childs': 'CH AY L D Z',
#  'comparatively': 'K AH M P AE R AH T IH V L IY',
#  'zebras': 'Z IY B R AH Z',
#  'availa': 'AH V EY L AH',
#  'sheet': 'SH IY T',
#  'attent': 'AH T EH N T',
#  'stiffness': 'S T IH F N AH S',
#  'buyers': 'B AY ER Z',
#  'further': 'F ER DH ER',
#  'contexts': 'K AA N T EH K S T S',
#  'matches': 'M AE CH AH Z',
#  'sketchboard': 'S K EH CH B AO R D',
#  'neglected': 'N AH G L EH K T AH D',
#  'washing': 'W AA SH IH NG',
#  'italy': 'IH T AH L IY',
#  'sabrina': 'S AH B R IY N AH',
#  'conceive': 'K AH N S IY V',
#  'trainable': 'T R EY N AH B AH L',
#  'plastics': 'P L AE S T IH K S',
#  'florescent': 'F L AO R EH S AH N T',
#  'enjoy': 'EH N JH OY',
#  'elaborated': 'IH L AE B ER EY T AH D',
#  'surfaced': 'S ER F IH S T',
#  'colourised': 'K AH L ER AY Z D',
#  'aspects': 'AE S P EH K T S',
#  'extractor': 'IH K S T R AE K T ER',
#  'clients': 'K L AY AH N T S',
#  'japanamation': 'JH AH P AE N AH M EY SH AH N',
#  'flipphone': 'F L IH P F OW N',
#  'shuffle': 'SH AH F AH L',
#  'userfriendly': 'Y UW Z ER F R EH N D L IY',
#  'cafeteria': 'K AE F AH T IH R IY AH',
#  'francine': 'F R AE N S IY N',
#  'compone': 'K AH M P OW N',
#  'arrive': 'ER AY V',
#  'perspectives': 'P ER S P EH K T IH V Z',
#  'suggests': 'S AH JH EH S T S',
#  'colourfuls': 'K AH L ER F AH L Z',
#  'diverting': 'D AY V ER T IH NG',
#  'trained': 'T R EY N D',
#  'wolfs': 'W UH L F S',
#  'operating': 'AA P ER EY T IH NG',
#  'overdone': 'OW V ER D AH N',
#  'earth': 'ER TH',
#  'penlight': 'P EH N L AY T',
#  'purposes': 'P ER P AH S AH Z',
#  'represented': 'R EH P R AH Z EH N T AH D',
#  'bearing': 'B EH R IH NG',
#  'somewhe': 'S AH M Y UW',
#  'revealed': 'R IH V IY L D',
#  'germany': 'JH ER M AH N IY',
#  'integrally': 'IH N T AH G R AH L IY',
#  'pointy': 'P OY N T IY',
#  'treble': 'T R EH B AH L',
#  'maintained': 'M EY N T EY N D',
#  'obsolete': 'AA B S AH L IY T',
#  'carrot': 'K AE R AH T',
#  'nijmegen': 'N IH JH M IH G AH N',
#  'experimented': 'IH K S P EH R AH M AH N T AH D',
#  'converts': 'K AA N V ER T S',
#  'pikachu': 'P IH K AA CH UW',
#  'detail': 'D IH T EY L',
#  'liquid': 'L IH K W AH D',
#  'retailers': 'R IY T EY L ER Z',
#  'revisiting': 'R IY V IH Z IH T IH NG',
#  'future': 'F Y UW CH ER',
#  'functioning': 'F AH NG K SH AH N IH NG',
#  'thoughtful': 'TH AO T F AH L',
#  'whistle': 'W IH S AH L',
#  'revolutionised': 'R EH V AH L UW SH AH N AY Z D',
#  'diodes': 'D AY OW D Z',
#  'cheesed': 'CH IY Z D',
#  'whats': 'W AH T S',
#  'frequencies': 'F R IY K W AH N S IY Z',
#  'sedentary': 'S EH D AH N T EH R IY',
#  'timewarp': 'T AY M W AO R P',
#  'heres': 'HH IH R Z',
#  'regardless': 'R AH G AA R D L AH S',
#  'reliability': 'R IY L AY AH B IH L AH T IY',
#  'receiving': 'R AH S IY V IH NG',
#  'constructs': 'K AH N S T R AH K T S',
#  'approx': 'AH P R AA K S',
#  'shellshaped': 'SH EH L SH EY P T',
#  'subliminal': 'S AH B L IH M IH N AH L',
#  'grease': 'G R IY S',
#  'researched': 'R IY S ER CH T',
#  'quadrants': 'K W AA D R AH N T S',
#  'interchan': 'IH N T ER CH AE N',
#  'naive': 'N AY IY V',
#  'sounder': 'S AW N D ER',
#  'cleanable': 'K L IY N AH B AH L',
#  'comes': 'K AH M Z',
#  'invested': 'IH N V EH S T AH D',
#  'context': 'K AA N T EH K S T',
#  'impending': 'IH M P EH N D IH NG',
#  'stupid': 'S T UW P AH D',
#  'hardcoded': 'HH AA R D K OW D IH D',
#  'power': 'P AW ER',
#  'attended': 'AH T EH N D AH D',
#  'effec': 'EH F EH K',
#  'magnetic': 'M AE G N EH T IH K',
#  'steadily': 'S T EH D AH L IY',
#  'repeating': 'R IH P IY T IH NG',
#  'amusing': 'AH M Y UW Z IH NG',
#  'topranked': 'T AH P R AE NG K T',
#  'tutorings': 'T UW T ER IH NG Z',
#  'seems': 'S IY M Z',
#  'awkward': 'AO K W ER D',
#  'doublecurve': 'D AH B AH L K ER V',
#  'maximising': 'M AE K S AH M AY Z IH NG',
#  'populated': 'P AA P Y AH L EY T AH D',
#  'bounce': 'B AW N S',
#  'juergen': 'Y ER G AH N',
#  'changeable': 'CH EY N JH AH B AH L',
#  'detailed': 'D IH T EY L D',
#  'compromise': 'K AA M P R AH M AY Z',
#  'pinging': 'P IH NG IH NG',
#  'encounter': 'IH N K AW N T ER',
#  'demokraphi': 'D IH M OW K R AA F IY',
#  'aggressive': 'AH G R EH S IH V',
#  'therell': 'TH EH R AH L',
#  'grade': 'G R EY D',
#  'success': 'S AH K S EH S',
#  'cognitive': 'K AA G N IH T IH V',
#  'highend': 'HH AY AH N D',
#  'evolved': 'IH V AA L V D',
#  'sixes': 'S IH K S IH Z',
#  'discriminate': 'D IH S K R IH M AH N EY T',
#  'ruled': 'R UW L D',
#  'versatile': 'V ER S AH T AH L',
#  'closest': 'K L OW S AH S T',
#  'detachable': 'D IH T AE CH AH B AH L',
#  'debate': 'D AH B EY T',
#  'attempting': 'AH T EH M P T IH NG',
#  'respet': 'R IH S P EH T',
#  'cancer': 'K AE N S ER',
#  'expression': 'IH K S P R EH SH AH N',
#  'breaking': 'B R EY K IH NG',
#  'rationale': 'R AE SH AH N AE L',
#  'october': 'AA K T OW B ER',
#  'relating': 'R IH L EY T IH NG',
#  'earli': 'ER L IY',
#  'joining': 'JH OY N IH NG',
#  'respondents': 'R IH S P AA N D AH N T S',
#  'carved': 'K AA R V D',
#  'alkaline': 'AE L K AH L AY N',
#  'disturbed': 'D IH S T ER B D',
#  'unstructured': 'AH N S T R AH K SH ER D',
#  'analyzer': 'AE N AH L AY Z ER',
#  'sleeping': 'S L IY P IH NG',
#  'evalua': 'EH V AA L Y UW AH',
#  'robins': 'R AA B AH N Z',
#  'version': 'V ER ZH AH N',
#  'concretely': 'K AA N K R IY T L IY',
#  'handi': 'HH AE N D IY',
#  'channelhopping': 'CH AE N AH L HH AA P IH NG',
#  'prioritized': 'P R AY AO R AH T AY Z D',
#  'tendency': 'T EH N D AH N S IY',
#  'sheep': 'SH IY P',
#  'laugh': 'L AE F',
#  'rapidly': 'R AE P AH D L IY',
#  'datas': 'D EY T AH Z',
#  'electrici': 'IH L EH K T R IY CH IY',
#  'requiremen': 'R IY K W AY R M AH N',
#  'recognisable': 'R EH K AH G N AY Z AH B AH L',
#  'whether': 'W EH DH ER',
#  'twiddle': 'T W IH D AH L',
#  'useful': 'Y UW S F AH L',
#  'funtionability': 'F AH N SH AH N AH B IH L IH T IY',
#  'uniquely': 'Y UW N IY K L IY',
#  'lately': 'L EY T L IY',
#  'rarity': 'R EH R AH T IY',
#  'increase': 'IH N K R IY S',
#  'implement': 'IH M P L AH M AH N T',
#  'weeny': 'W IY N IY',
#  'reminder': 'R IY M AY N D ER',
#  'limits': 'L IH M AH T S',
#  'disaster': 'D IH Z AE S T ER',
#  'scented': 'S EH N T IH D',
#  'liking': 'L AY K IH NG',
#  'gambling': 'G AE M B AH L IH NG',
#  'walking': 'W AO K IH NG',
#  'kittycat': 'K IH T IY K AE T',
#  'intro': 'IH N T R OW',
#  'catchy': 'K AE CH IY',
#  'joysticks': 'JH OY S T IH K S',
#  'informa': 'IH N F AO R M AH',
#  'reconsider': 'R IY K AH N S IH D ER',
#  'wonderful': 'W AH N D ER F AH L',
#  'wraps': 'R AE P S',
#  'agreeing': 'AH G R IY IH NG',
#  'prioritising': 'P R AY AO R AH T AY Z IH NG',
#  'burritos': 'B ER IY T OW S',
#  'multiformat': 'M AH L T IY F AO R M AH T',
#  'winner': 'W IH N ER',
#  'schedules': 'S K EH JH UH L Z',
#  'irritate': 'IH R IH T EY T',
#  'acupressure': 'AE K Y AH P R EH SH ER',
#  'books': 'B UH K S',
#  'mistake': 'M IH S T EY K',
#  'spats': 'S P AE T S',
#  'industry': 'IH N D AH S T R IY',
#  'loosen': 'L UW S AH N',
#  'decent': 'D IY S AH N T',
#  'clunker': 'K L AH NG K ER',
#  'financi': 'F IH N AE N CH IY',
#  'record': 'R AH K AO R D',
#  'blockbooked': 'B L AA K B UH K T',
#  'vulnerab': 'V AH L N ER AE B',
#  'sincerely': 'S IH N S IH R L IY',
#  'together': 'T AH G EH DH ER',
#  'betty': 'B EH T IY',
#  'kingdom': 'K IH NG D AH M',
#  'fruitiness': 'F R UW T IY N AH S',
#  'imagi': 'IH M AA G IY',
#  'traversal': 'T R AH V ER S AH L',
#  'emailing': 'IY M EY L IH NG',
#  'extraordinary': 'EH K S T R AH AO R D AH N EH R IY',
#  'fingernail': 'F IH NG G ER N EY L',
#  'experimental': 'IH K S P EH R IH M EH N T AH L',
#  'champagne': 'SH AE M P EY N',
#  'corporation': 'K AO R P ER EY SH AH N',
#  'ineffective': 'IH N IH F EH K T IH V',
#  'fascias': 'F AE SH AH S',
#  'still': 'S T IH L',
#  'magnitude': 'M AE G N AH T UW D',
#  'grandkids': 'G R AE N D K IH D Z',
#  'repeats': 'R IH P IY T S',
#  'pains': 'P EY N Z',
#  'nonremovable': 'N AA N R IH M UW V AH B AH L',
#  'discursive': 'D IH S K ER S IH V',
#  'congratulations': 'K AH N G R AE CH AH L EY SH AH N Z',
#  'weights': 'W EY T S',
#  'published': 'P AH B L IH SH T',
#  'short': 'SH AO R T',
#  'nokia': 'N OW K IY AH',
#  'snout': 'S N AW T',
#  'monochrome': 'M AA N AH K R OW M',
#  'upgraded': 'AH P G R EY D AH D',
#  'manipulating': 'M AH N IH P Y AH L EY T IH NG',
#  'gravity': 'G R AE V AH T IY',
#  'yourselves': 'Y UH R S EH L V Z',
#  'desktop': 'D EH S K T AA P',
#  'silvers': 'S IH L V ER Z',
#  'heard': 'HH ER D',
#  'voiceover': 'V OY S OW V ER',
#  'experiments': 'IH K S P EH R AH M AH N T S',
#  'explanatory': 'IH K S P L AE N AH T AO R IY',
#  'ought': 'AO T',
#  'gaurav': 'G AO R AA V',
#  'coaches': 'K OW CH IH Z',
#  'idiom': 'IH D IY AH M',
#  'continuity': 'K AA N T AH N UW AH T IY',
#  'revisit': 'R IY V IH Z IH T',
#  'platform': 'P L AE T F AO R M',
#  'misgroup': 'M IH S G R UW P',
#  'suede': 'S W EY D',
#  'megafile': 'M EH G AH F AY L',
#  'inwards': 'IH N W ER D Z',
#  'contrary': 'K AA N T R EH R IY',
#  'gonna': 'G AA N AH',
#  'table': 'T EY B AH L',
#  'proba': 'P R OW B AA',
#  'comfier': 'K AH M F IY ER',
#  'primitive': 'P R IH M AH T IH V',
#  'browser': 'B R AW Z ER',
#  'scarily': 'S K EH R AH L IY',
#  'drawable': 'D R AA W AH B AH L',
#  'minut': 'M IH N AH T',
#  'creature': 'K R IY CH ER',
#  'timer': 'T AY M ER',
#  'tendonditis': 'T EH N D AA N D AH T IH S',
#  'visit': 'V IH Z IH T',
#  'doubleclick': 'D AH B L IH K L IH K',
#  'plain': 'P L EY N',
#  'smooth': 'S M UW DH',
#  'simulates': 'S IH M Y AH L EY T S',
#  'adapted': 'AH D AE P T IH D',
#  'particular': 'P ER T IH K Y AH L ER',
#  'succe': 'S AH K S',
#  'dropdown': 'D R AA P D AW N',
#  'coding': 'K OW D IH NG',
#  'committing': 'K AH M IH T IH NG',
#  'swords': 'S AO R D Z',
#  'behave': 'B IH HH EY V',
#  'vertex': 'V ER T EH K S',
#  'vector': 'V EH K T ER',
#  'actively': 'AE K T IH V L IY',
#  'stylist': 'S T AY L IH S T',
#  'gesture': 'JH EH S CH ER',
#  'inquire': 'IH N K W AY R',
#  'younger': 'Y AH NG G ER',
#  'poking': 'P OW K IH NG',
#  'existence': 'EH G Z IH S T AH N S',
#  'characteris': 'K EH R AH K T EH R IH S',
#  'jirun': 'JH IH R AH N',
#  'cambodia': 'K AE M B OW D IY AH',
#  'turned': 'T ER N D',
#  'screams': 'S K R IY M Z',
#  'viewing': 'V Y UW IH NG',
#  'devices': 'D IH V AY S AH Z',
#  'leftclick': 'L EH F T K L IH K',
#  'coffee': 'K AA F IY',
#  'controllers': 'K AH N T R OW L ER Z',
#  'impulse': 'IH M P AH L S',
#  'newsflash': 'N UW S F L AE SH',
#  'texture': 'T EH K S CH ER',
#  'tshaped': 'CH EY P T',
#  'caramel': 'K EH R AH M AH L',
#  'spellcheck': 'S P EH L CH EH K',
#  'acknowledged': 'AE K N AA L IH JH D',
#  'especialised': 'IH S P EH SH AH L AY Z D',
#  'crotch': 'K R AA CH',
#  'horrendously': 'HH AO R EH N D AH S L IY',
#  'follows': 'F AA L OW Z',
#  'reduces': 'R IH D UW S IH Z',
#  'reporting': 'R IY P AO R T IH NG',
#  'temps': 'T EH M P S',
#  'stage': 'S T EY JH',
#  'timeframe': 'T AY M F R EY M',
#  'smarter': 'S M AA R T ER',
#  'olivier': 'OW L IH V IY EY',
#  'price': 'P R AY S',
#  'selfdestructible': 'S EH L F D IH S T R AH K T IH B AH L',
#  'energy': 'EH N ER JH IY',
#  'abilities': 'AH B IH L AH T IY Z',
#  'unsupportive': 'AH N S AH P AO R T IH V',
#  'cease': 'S IY S',
#  'midair': 'M IH D EH R',
#  'specify': 'S P EH S AH F AY',
#  'goodlooking': 'G UH D L UH K IH NG',
#  'nonissue': 'N AA N IH S UW',
#  'hands': 'HH AE N D Z',
#  'childishly': 'CH AY L D IH SH L IY',
#  'appreciated': 'AH P R IY SH IY EY T IH D',
#  'functionally': 'F AH NG K SH AH N AH L IY',
#  'extension': 'IH K S T EH N SH AH N',
#  'practicalit': 'P R AE K T IH K AE L AH T',
#  'increa': 'IH N K R IY AH',
#  'investi': 'IH N V EH S T IY',
#  'aubergines': 'AW B ER JH IY N Z',
#  'thumbs': 'TH AH M Z',
#  'taiwan': 'T AY W AA N',
#  'duplicating': 'D UW P L IH K EY T IH NG',
#  'restriction': 'R IY S T R IH K SH AH N',
#  'sponginess': 'S P AH N JH IY N AH S',
#  'vasilis': 'V AH S IH L AH S',
#  'frustrates': 'F R AH S T R EY T S',
#  'reload': 'R IY L OW D',
#  'intuitively': 'IH N T UW IH T IH V L IY',
#  'where': 'W EH R',
#  'preclude': 'P R IH K L UW D',
#  'audible': 'AA D AH B AH L',
#  'hills': 'HH IH L Z',
#  'plasticky': 'P L AH S T IH K IY',
#  'telewest': 'T EH L AH W EH S T',
#  'software': 'S AO F T W EH R',
#  'grand': 'G R AE N D',
#  'snapshot': 'S N AE P SH AA T',
#  'living': 'L IH V IH NG',
#  'thosell': 'TH AA S AH L',
#  'incorporated': 'IH N K AO R P ER EY T IH D',
#  'beast': 'B IY S T',
#  'burnt': 'B ER N T',
#  'unmarked': 'AH N M AA R K T',
#  'facials': 'F EY SH AH L Z',
#  'optimist': 'AA P T IH M IH S T',
#  'unders': 'AH N D ER Z',
#  'participate': 'P AA R T IH S AH P EY T',
#  'calculate': 'K AE L K Y AH L EY T',
#  'pseudoface': 'S UW D OW F EY S',
#  'learning': 'L ER N IH NG',
#  'consu': 'K AA N S UW',
#  'updates': 'AH P D EY T S',
#  'socket': 'S AA K AH T',
#  'thousand': 'TH AW Z AH N D',
#  'handle': 'HH AE N D AH L',
#  'strawberrys': 'S T R AO B EH R IY Z',
#  'bebacks': 'B IY B AE K S',
#  'fiddle': 'F IH D AH L',
#  'frankenstein': 'F R AE NG K AH N S T AY N',
#  'microphoneesque': 'M AY K R OW F OW N IY S K',
#  'perhaps': 'P ER HH AE P S',
#  'contacts': 'K AA N T AE K T S',
#  'lunchtime': 'L AH N CH T AY M',
#  'generates': 'JH EH N ER EY T S',
#  'adaptive': 'AH D AE P T IH V',
#  'naming': 'N EY M IH NG',
#  'automated': 'AO T AH M EY T IH D',
#  'ceilings': 'S IY L IH NG Z',
#  'whiteboard': 'W AY T B AO R D',
#  'coach': 'K OW CH',
#  'wanker': 'W AA NG K ER',
#  'multifunction': 'M AH L T IY F AH NG K SH AH N',
#  'ceefax': 'S IY F AE K S',
#  'floods': 'F L AH D Z',
#  'financial': 'F AH N AE N SH AH L',
#  'nineteenth': 'N AY N T IY N TH',
#  'grain': 'G R EY N',
#  'sides': 'S AY D Z',
#  'getting': 'G EH T IH NG',
#  'envisaged': 'EH N V IH Z IH JH D',
#  'dinner': 'D IH N ER',
#  'exposition': 'EH K S P AH Z IH SH AH N',
#  'capacitor': 'K AH P AE S AH T ER',
#  'bound': 'B AW N D',
#  'pineapple': 'P AY N AE P AH L',
#  'agrees': 'AH G R IY Z',
#  'surfing': 'S ER F IH NG',
#  'sketch': 'S K EH CH',
#  'amounts': 'AH M AW N T S',
#  'surprised': 'S ER P R AY Z D',
#  'reall': 'R IY L',
#  'played': 'P L EY D',
#  'rightclicking': 'R AY T K L IH K IH NG',
#  'highly': 'HH AY L IY',
#  'benchmarking': 'B EH N CH M AA R K IH NG',
#  'eeyore': 'IY Y AO R',
#  'indiv': 'IH N D IH V',
#  'hellbent': 'HH EH L B AH N T',
#  'vegetabley': 'V EH JH AH T AH B L IY',
#  'teaser': 'T IY Z ER',
#  'housing': 'HH AW Z IH NG',
#  'cloak': 'K L OW K',
#  'perfectly': 'P ER F AH K T L IY',
#  'fight': 'F AY T',
#  'overhead': 'OW V ER HH EH D',
#  'swiftly': 'S W IH F T L IY',
#  'foundation': 'F AW N D EY SH AH N',
#  'respective': 'R IH S P EH K T IH V',
#  'numbering': 'N AH M B ER IH NG',
#  'offended': 'AH F EH N D AH D',
#  'louder': 'L AW D ER',
#  'dumps': 'D AH M P S',
#  'specifies': 'S P EH S AH F AY Z',
#  'wearing': 'W EH R IH NG',
#  'survey': 'S ER V EY',
#  'industr': 'IH N D AH S T ER',
#  'thinking': 'TH IH NG K IH NG',
#  'leaning': 'L IY N IH NG',
#  'everyone': 'EH V R IY W AH N',
#  'indepen': 'IH N D IH P AH N',
#  'phonetically': 'F AH N EH T IH K L IY',
#  'thinks': 'TH IH NG K S',
#  'cellphone': 'S EH L F OW N',
#  'graphs': 'G R AE F S',
#  'design': 'D IH Z AY N',
#  'hmhmm': 'HH AH M EH M',
#  'dialects': 'D AY AH L EH K T S',
#  'beaver': 'B IY V ER',
#  'circuitry': 'S ER K AH T R IY',
#  'imagine': 'IH M AE JH AH N',
#  'consists': 'K AH N S IH S T S',
#  'weigh': 'W EY',
#  'trains': 'T R EY N Z',
#  'monotonic': 'M AA N AH T AA N IH K',
#  'accomplish': 'AH K AA M P L IH SH',
#  'rasta': 'R AE S T AH',
#  'flaws': 'F L AO Z',
#  'contrast': 'K AA N T R AE S T',
#  'eaten': 'IY T AH N',
#  'prolong': 'P R AH L AO NG',
#  'belgium': 'B EH L JH AH M',
#  'worker': 'W ER K ER',
#  'twenty': 'T W EH N T IY',
#  'frequent': 'F R IY K W AH N T',
#  'remem': 'R EH M AH M',
#  'remarking': 'R IH M AA R K IH NG',
#  'major': 'M EY JH ER',
#  'softer': 'S AA F T ER',
#  'pushable': 'P UH SH AH B AH L',
#  'illumination': 'IH L UW M AH N EY SH AH N',
#  'costly': 'K AA S T L IY',
#  'correlation': 'K AO R AH L EY SH AH N',
#  'tinkering': 'T IH NG K ER IH NG',
#  'queries': 'K W IH R IY Z',
#  'coordinated': 'K OW AO R D AH N EY T IH D',
#  'semester': 'S AH M EH S T ER',
#  'jogdial': 'JH AA G D IY AH L',
#  'refresh': 'R IH F R EH SH',
#  'synchs': 'S IH N CH IH Z',
#  'quantify': 'K W AA N T IH F AY',
#  'tiered': 'T IY R D',
#  'timetables': 'T AY M T EY B AH L Z',
#  'summarisers': 'S AH M ER AY Z ER Z',
#  'pensioners': 'P EH N SH AH N ER Z',
#  'hilarious': 'HH IH L EH R IY AH S',
#  'babas': 'B AA B AH Z',
#  'light': 'L AY T',
#  'comparable': 'K AA M P R AH B AH L',
#  'versus': 'V ER S AH S',
#  'teenager': 'T IY N EY JH ER',
#  'neater': 'N IY T ER',
#  'reset': 'R IY S EH T',
#  'tightly': 'T AY T L IY',
#  'clouds': 'K L AW D Z',
#  'alrigh': 'AE L R AY',
#  'softwares': 'S AO F W EH R Z',
#  'engineers': 'EH N JH AH N IH R Z',
#  'photocopy': 'F OW T OW K AA P IY',
#  'macro': 'M AE K R OW',
#  'suppl': 'S AH P AH L',
#  'sideways': 'S AY D W EY Z',
#  'worldwide': 'W ER L D W AY D',
#  'untitled': 'AH N T AY T AH L D',
#  'bumblebeeish': 'B AH M B AH L B IY SH',
#  'reckoning': 'R EH K AH N IH NG',
#  'functionalitywise': 'F AH NG K SH AH N AH L IH T AH T IH W IH Z',
#  'carryon': 'K AE R IY AH N',
#  'advantageous': 'AE D V AH N T EY JH AH S',
#  'directions': 'D ER EH K SH AH N Z',
#  'bulges': 'B AH L JH IH Z',
#  'sizable': 'S AY Z AH B AH L',
#  'interfacing': 'IH N T ER F EY S IH NG',
#  'japan': 'JH AH P AE N',
#  'seeds': 'S IY D Z',
#  'saver': 'S EY V ER',
#  'pennies': 'P EH N IY Z',
#  'split': 'S P L IH T',
#  'cooler': 'K UW L ER',
#  'eighty': 'EY T IY',
#  'infro': 'IH N F R OW',
#  'states': 'S T EY T S',
#  'reintegrate': 'R IY IH N T AH G R EY T',
#  'novel': 'N AA V AH L',
#  'grossly': 'G R OW S L IY',
#  'bullet': 'B UH L AH T',
#  'mysterious': 'M IH S T IH R IY AH S',
#  'docking': 'D AA K IH NG',
#  'surrounding': 'S ER AW N D IH NG',
#  'introduce': 'IH N T R AH D UW S',
#  'location': 'L OW K EY SH AH N',
#  'whoever': 'HH UW EH V ER',
#  'interject': 'IH N T ER JH EH K T',
#  'colin': 'K OW L IH N',
#  'dormant': 'D AO R M AH N T',
#  'surprisingly': 'S ER P R AY Z IH NG L IY',
#  'websites': 'W EH B S AY T S',
#  'quasar': 'K W EY Z AA R',
#  'sturdy': 'S T ER D IY',
#  'wouldve': 'W UH L D V',
#  'association': 'AH S OW S IY EY SH AH N',
#  ...}

# %%
alignSequences.align(word_phoneme_dict["pixel"],word_phoneme_dict["finds"])
# Out:
# ('P IH K S AH L', '- F AY N D Z', 6)

# %%
#Load word pred dictionaries
snr_strings = ["clean"] + ["snr%d"%(snr) for snr in [20,5,0,-5] ]
word_to_pred_dicts = {}
y_pred_labels_matrices = []
for snr_string in snr_strings:
    word_to_pred_dicts[snr_string] = np.load("Data/%s_word_to_pred.npy"%(snr_string), allow_pickle = True).item()

# %%
edit_distances_dict = {}
for snr_string,word_to_pred_dict in word_to_pred_dicts.items():
    edit_distances_dict[snr_string] = []
    for test_word,predicted_words in word_to_pred_dict.items():
        for predicted_word in predicted_words:
            aligned_seq1, aligned_seq2, eDistance = alignSequences.align(word_phoneme_dict[test_word], word_phoneme_dict[predicted_word])
            edit_distances_dict[snr_string].append(eDistance)

# %%
phoneme_lens = [len(val.split()) for key,val in word_phoneme_dict.items()]
plt.hist(phoneme_lens)
plt.title("Number of Phonemes of words in Dataset")
plt.xlabel("Number of Phonemes")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
def filter_zeros(edit_distances):
    edit_distances = [val for val in edit_distances if val!= 0 ]
    
    return edit_distances

# %%
def give_skew_and_kurt(edit_distances):
    
    curr_skew = skew(filter_zeros(edit_distances))
    curr_kurt = kurtosis(filter_zeros(edit_distances))
    
    return curr_skew, curr_kurt

# %%
snr_string = "snr-5"
print(kurtosis(filter_zeros(edit_distances_dict[snr_string])))
print(skew(filter_zeros(edit_distances_dict[snr_string])))
# Out:
# 0.6329391447371613
# 0.33991491853192984

# %%
snr_string = "clean"
plt.hist(filter_zeros(edit_distances_dict[snr_string]))
curr_skew, curr_kurt = give_skew_and_kurt(edit_distances_dict["clean"])
plt.title("PhED of Classifications %s Dataset (Skew %.2f Kurtosis %.2f)"%(snr_string, curr_skew, curr_kurt))
plt.xlabel("Phoneme Edit Distance")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
fig, axs = plt.subplots(2, 2, figsize=(10,10))
fig.suptitle('PhED of Classification Histogram')

#SNR 20
axs[0, 0].hist(filter_zeros(edit_distances_dict["snr20"]))
curr_skew, curr_kurt = give_skew_and_kurt(edit_distances_dict["snr20"])
axs[0, 0].set_title('SNR 20 Dataset (Skew %.2f Kurtosis %.2f)'%(curr_skew, curr_kurt))

#SNR 5
axs[0, 1].hist(filter_zeros(edit_distances_dict["snr5"]))
curr_skew, curr_kurt = give_skew_and_kurt(edit_distances_dict["snr5"])
axs[0, 1].set_title('SNR 5 Dataset (Skew %.2f Kurtosis %.2f)'%(curr_skew, curr_kurt))

#SNR 0
axs[1, 0].hist(filter_zeros(edit_distances_dict["snr0"]))
curr_skew, curr_kurt = give_skew_and_kurt(edit_distances_dict["snr0"])
axs[1, 0].set_title('SNR 0 Dataset (Skew %.2f Kurtosis %.2f)'%(curr_skew, curr_kurt))

#SNR -5
axs[1, 1].hist(filter_zeros(edit_distances_dict["snr-5"]))
curr_skew, curr_kurt = give_skew_and_kurt(edit_distances_dict["snr-5"])
axs[1, 1].set_title('SNR -5 Dataset (Skew %.2f Kurtosis %.2f)'%(curr_skew, curr_kurt))

#x,y labels
for ax in axs.flat:
    ax.set(xlabel='Phoneme Edit Distance', ylabel='Frequency')

# %% [markdown]
# ## 5. Update Word Phoneme Dict

# %%
from big_phoney import BigPhoney
# Out:
# Using TensorFlow backend.

# %%
def filter_alphabets(string):
    return ''.join(e for e in string if (e.isalpha() or e.isspace()))

# %%
phoney = BigPhoney()

# %%
count = 0
for key in clean_word_to_num.keys():

    if key not in word_phoneme_dict.keys():
        print("Adding %s Count %d"%(key,count))
        word_phoneme_dict[key] = filter_alphabets(phoney.phonize(key))
        count+= 1

print(count)
# Out:
# Adding tfidf Count 0
# Adding bdboo Count 1
# Adding nlssd Count 2
# Adding tdidf Count 3
# Adding spnlp Count 4
# Adding ctiio Count 5
# Adding xhtml Count 6
# Adding antirsi Count 7
# Adding importantcause Count 8
# Adding idvidnme Count 9
# Adding preferencesyeah Count 10
# Adding apogee Count 11
# Adding mailbox Count 12
# Adding reasearch Count 13
# Adding cupboards Count 14
# Adding southwest Count 15
# Adding sunrise Count 16
# Adding northeast Count 17
# Adding sunset Count 18
# Adding marianne Count 19
# Adding mariannes Count 20
# Adding gisella Count 21
# Adding humanly Count 22
# Adding courtyard Count 23
# Adding reserving Count 24
# Adding cafeterias Count 25
# Adding stagieur Count 26
# Adding bookshelves Count 27
# Adding minilibrary Count 28
# Adding collegues Count 29
# Adding mountains Count 30
# Adding mailboxes Count 31
# Adding stagieurs Count 32
# Adding orienting Count 33
# Adding bathrooms Count 34
# Adding elevators Count 35
# Adding professors Count 36
# Adding administrators Count 37
# Adding networked Count 38
# Adding printers Count 39
# Adding halfcircular Count 40
# Adding issco Count 41
# Adding summertime Count 42
# Adding trainees Count 43
# Adding southeast Count 44
# Adding assistent Count 45
# Adding maggie Count 46
# Adding susan Count 47
# Adding nancy Count 48
# Adding pirette Count 49
# Adding skive Count 50
# Adding skiving Count 51
# Adding unadvantaged Count 52
# Adding bruno Count 53
# Adding sixth Count 54
# Adding receivi Count 55
# Adding exams Count 56
# Adding dictatorship Count 57
# Adding vending Count 58
# Adding smokers Count 59
# Adding pierrette Count 60
# Adding architect Count 61
# Adding welcoming Count 62
# Adding nonpermanent Count 63
# Adding andrei Count 64
# Adding yalina Count 65
# Adding maria Count 66
# Adding gossiping Count 67
# Adding photocopying Count 68
# Adding misunderstand Count 69
# Adding reduction Count 70
# Adding nespresso Count 71
# Adding nonsmoking Count 72
# Adding gisellas Count 73
# Adding nikos Count 74
# Adding premindia Count 75
# Adding parmenidy Count 76
# Adding parmenidies Count 77
# Adding martha Count 78
# Adding parttime Count 79
# Adding permutations Count 80
# Adding optimum Count 81
# Adding halftime Count 82
# Adding cubicles Count 83
# Adding contiguous Count 84
# Adding assistants Count 85
# Adding furnishing Count 86
# Adding intern Count 87
# Adding separations Count 88
# Adding corridor Count 89
# Adding filing Count 90
# Adding regulation Count 91
# Adding toilets Count 92
# Adding oneperson Count 93
# Adding tradition Count 94
# Adding shaft Count 95
# Adding cabinet Count 96
# Adding shelves Count 97
# Adding drawers Count 98
# Adding faculty Count 99
# Adding socioeconomics Count 100
# Adding privacy Count 101
# Adding insofar Count 102
# Adding rectorate Count 103
# Adding confidential Count 104
# Adding balcony Count 105
# Adding underused Count 106
# Adding valorize Count 107
# Adding administrative Count 108
# Adding authorisation Count 109
# Adding politically Count 110
# Adding accommodating Count 111
# Adding admin Count 112
# Adding nonresearcher Count 113
# Adding visiting Count 114
# Adding multiconstraint Count 115
# Adding stinct Count 116
# Adding vivid Count 117
# Adding emergency Count 118
# Adding confidentiality Count 119
# Adding progressively Count 120
# Adding imtwo Count 121
# Adding swisstra Count 122
# Adding smoker Count 123
# Adding reluctant Count 124
# Adding walkman Count 125
# Adding calmer Count 126
# Adding balancing Count 127
# Adding genders Count 128
# Adding demanded Count 129
# Adding scientific Count 130
# Adding mysel Count 131
# Adding paola Count 132
# Adding admins Count 133
# Adding circulate Count 134
# Adding prefinal Count 135
# Adding lightbrown Count 136
# Adding violet Count 137
# Adding fewest Count 138
# Adding earplugs Count 139
# Adding sexes Count 140
# Adding divider Count 141
# Adding marias Count 142
# Adding occupancy Count 143
# Adding november Count 144
# Adding workplace Count 145
# Adding lounges Count 146
# Adding decently Count 147
# Adding welcomed Count 148
# Adding provocative Count 149
# Adding stabler Count 150
# Adding opposition Count 151
# Adding defendable Count 152
# Adding proposition Count 153
# Adding horizon Count 154
# Adding corresponds Count 155
# Adding reshuffled Count 156
# Adding overloaded Count 157
# Adding floors Count 158
# Adding partitions Count 159
# Adding argumentation Count 160
# Adding armchairs Count 161
# Adding displace Count 162
# Adding minimeeting Count 163
# Adding bookshelf Count 164
# Adding magazine Count 165
# Adding fullblown Count 166
# Adding fluctuates Count 167
# Adding finnish Count 168
# Adding interns Count 169
# Adding backfire Count 170
# Adding lausanne Count 171
# Adding statutes Count 172
# Adding decole Count 173
# Adding andre Count 174
# Adding cathedral Count 175
# Adding lavish Count 176
# Adding partition Count 177
# Adding bookcases Count 178
# Adding hightraffic Count 179
# Adding restrooms Count 180
# Adding unuseful Count 181
# Adding swedish Count 182
# Adding womens Count 183
# Adding norms Count 184
# Adding insist Count 185
# Adding arrives Count 186
# Adding parmenides Count 187
# Adding yalinas Count 188
# Adding defended Count 189
# Adding insisted Count 190
# Adding gisel Count 191
# Adding nominal Count 192
# Adding journals Count 193
# Adding administrate Count 194
# Adding nominated Count 195
# Adding awards Count 196
# Adding disheartened Count 197
# Adding psychologist Count 198
# Adding emotional Count 199
# Adding gangster Count 200
# Adding liotta Count 201
# Adding lecter Count 202
# Adding hopkins Count 203
# Adding suburban Count 204
# Adding psychopaths Count 205
# Adding fantasises Count 206
# Adding mainstream Count 207
# Adding predominantly Count 208
# Adding reenhanced Count 209
# Adding damon Count 210
# Adding graveyard Count 211
# Adding suspects Count 212
# Adding fiction Count 213
# Adding tarantino Count 214
# Adding ascension Count 215
# Adding mcquarrie Count 216
# Adding byrne Count 217
# Adding criminals Count 218
# Adding arrested Count 219
# Adding prison Count 220
# Adding crime Count 221
# Adding coincidence Count 222
# Adding ubervillain Count 223
# Adding funniest Count 224
# Adding shyamalan Count 225
# Adding osment Count 226
# Adding collette Count 227
# Adding apocalypse Count 228
# Adding amadeus Count 229
# Adding dramatic Count 230
# Adding actioney Count 231
# Adding actor Count 232
# Adding viewers Count 233
# Adding mononoke Count 234
# Adding kieslowski Count 235
# Adding coleurs Count 236
# Adding danish Count 237
# Adding alternates Count 238
# Adding arabia Count 239
# Adding vietnam Count 240
# Adding drama Count 241
# Adding humanistic Count 242
# Adding glorification Count 243
# Adding nazis Count 244
# Adding soldier Count 245
# Adding government Count 246
# Adding camels Count 247
# Adding battles Count 248
# Adding spielberg Count 249
# Adding cimena Count 250
# Adding cinematography Count 251
# Adding documentaries Count 252
# Adding miller Count 253
# Adding caption Count 254
# Adding sacrifices Count 255
# Adding humorous Count 256
# Adding controversies Count 257
# Adding zetajones Count 258
# Adding chandler Count 259
# Adding lebowskis Count 260
# Adding nominate Count 261
# Adding mirek Count 262
# Adding nominees Count 263
# Adding nominee Count 264
# Adding nominations Count 265
# Adding denis Count 266
# Adding lebowski Count 267
# Adding schindlers Count 268
# Adding lambs Count 269
# Adding ascensions Count 270
# Adding liberation Count 271
# Adding camps Count 272
# Adding liberated Count 273
# Adding coherence Count 274
# Adding encouraging Count 275
# Adding decrypt Count 276
# Adding foster Count 277
# Adding masterpiece Count 278
# Adding scorseses Count 279
# Adding godfather Count 280
# Adding thrillers Count 281
# Adding agent Count 282
# Adding psychopathic Count 283
# Adding psychotic Count 284
# Adding anthony Count 285
# Adding penetrating Count 286
# Adding poetic Count 287
# Adding influencing Count 288
# Adding occasion Count 289
# Adding forman Count 290
# Adding psychopath Count 291
# Adding filming Count 292
# Adding schin Count 293
# Adding cannes Count 294
# Adding nonhero Count 295
# Adding stories Count 296
# Adding moralistic Count 297
# Adding nonviolent Count 298
# Adding fargo Count 299
# Adding cruel Count 300
# Adding suburb Count 301
# Adding bowling Count 302
# Adding goodman Count 303
# Adding turturro Count 304
# Adding buscemi Count 305
# Adding surrealistic Count 306
# Adding jeffrey Count 307
# Adding ethnographic Count 308
# Adding subscrip Count 309
# Adding subscription Count 310
# Adding quotations Count 311
# Adding contradictory Count 312
# Adding agness Count 313
# Adding affranchis Count 314
# Adding mafia Count 315
# Adding thurman Count 316
# Adding endings Count 317
# Adding mysteries Count 318
# Adding twists Count 319
# Adding disgusting Count 320
# Adding redemption Count 321
# Adding bening Count 322
# Adding rewatch Count 323
# Adding notably Count 324
# Adding thriller Count 325
# Adding actiony Count 326
# Adding cesar Count 327
# Adding showings Count 328
# Adding violently Count 329
# Adding normandy Count 330
# Adding filmed Count 331
# Adding anonymously Count 332
# Adding greyish Count 333
# Adding darkish Count 334
# Adding uniforms Count 335
# Adding weapons Count 336
# Adding resentful Count 337
# Adding christian Count 338
# Adding funnier Count 339
# Adding treatment Count 340
# Adding enjoyable Count 341
# Adding freer Count 342
# Adding spans Count 343
# Adding evadees Count 344
# Adding poignant Count 345
# Adding clubbers Count 346
# Adding boxer Count 347
# Adding statistically Count 348
# Adding deniss Count 349
# Adding darabont Count 350
# Adding freshest Count 351
# Adding victory Count 352
# Adding starling Count 353
# Adding hannibal Count 354
# Adding simulati Count 355
# Adding shawshank Count 356
# Adding trivias Count 357
# Adding advertisements Count 358
# Adding sleepi Count 359
# Adding dufresne Count 360
# Adding witnesses Count 361
# Adding horrors Count 362
# Adding endured Count 363
# Adding comeback Count 364
# Adding goodfellas Count 365
# Adding lebowksi Count 366
# Adding veteran Count 367
# Adding apartment Count 368
# Adding moore Count 369
# Adding mondre Count 370
# Adding killers Count 371
# Adding morbid Count 372
# Adding swapped Count 373
# Adding adver Count 374
# Adding kevin Count 375
# Adding simulating Count 376
# Adding baths Count 377
# Adding favou Count 378
# Adding robbins Count 379
# Adding freeman Count 380
# Adding registration Count 381
# Adding histogram Count 382
# Adding bhattacharya Count 383
# Adding downsampling Count 384
# Adding kayaks Count 385
# Adding regenerate Count 386
# Adding dissolve Count 387
# Adding incrustation Count 388
# Adding cinetis Count 389
# Adding whiter Count 390
# Adding enhancement Count 391
# Adding restoration Count 392
# Adding clustering Count 393
# Adding stabilisation Count 394
# Adding ultim Count 395
# Adding organi Count 396
# Adding compensation Count 397
# Adding reproduced Count 398
# Adding histograms Count 399
# Adding decomposition Count 400
# Adding cache Count 401
# Adding manmade Count 402
# Adding wishable Count 403
# Adding resay Count 404
# Adding subshots Count 405
# Adding scrambled Count 406
# Adding scramble Count 407
# Adding stones Count 408
# Adding sebastien Count 409
# Adding algori Count 410
# Adding downsam Count 411
# Adding kayak Count 412
# Adding outputting Count 413
# Adding outputted Count 414
# Adding developers Count 415
# Adding grabbed Count 416
# Adding executable Count 417
# Adding alessandro Count 418
# Adding protections Count 419
# Adding listable Count 420
# Adding reprocessing Count 421
# Adding reprocess Count 422
# Adding consecutive Count 423
# Adding latency Count 424
# Adding subthreshold Count 425
# Adding rhythmia Count 426
# Adding resize Count 427
# Adding cropping Count 428
# Adding producer Count 429
# Adding streaming Count 430
# Adding investigating Count 431
# Adding structuring Count 432
# Adding subshot Count 433
# Adding anytimes Count 434
# Adding dissolves Count 435
# Adding internship Count 436
# Adding supervision Count 437
# Adding jeanmarc Count 438
# Adding greek Count 439
# Adding organisation Count 440
# Adding quotation Count 441
# Adding recoverable Count 442
# Adding utilised Count 443
# Adding tolerant Count 444
# Adding normalised Count 445
# Adding likelihoods Count 446
# Adding posteriors Count 447
# Adding sprinklers Count 448
# Adding optimisation Count 449
# Adding prewritten Count 450
# Adding computed Count 451
# Adding posterior Count 452
# Adding enhancing Count 453
# Adding contextual Count 454
# Adding verifying Count 455
# Adding regenera Count 456
# Adding regenerating Count 457
# Adding regenerated Count 458
# Adding inversion Count 459
# Adding penalty Count 460
# Adding multistream Count 461
# Adding deltas Count 462
# Adding traps Count 463
# Adding interspeech Count 464
# Adding formally Count 465
# Adding formalism Count 466
# Adding probablility Count 467
# Adding encode Count 468
# Adding topological Count 469
# Adding recursions Count 470
# Adding evidences Count 471
# Adding introducing Count 472
# Adding likelihood Count 473
# Adding likelihoo Count 474
# Adding phonebook Count 475
# Adding monophone Count 476
# Adding triphone Count 477
# Adding monophones Count 478
# Adding notifies Count 479
# Adding recovery Count 480
# Adding recovered Count 481
# Adding truncated Count 482
# Adding gammas Count 483
# Adding triphones Count 484
# Adding iteration Count 485
# Adding iterations Count 486
# Adding completing Count 487
# Adding underground Count 488
# Adding hemants Count 489
# Adding databases Count 490
# Adding insure Count 491
# Adding perplexity Count 492
# Adding categorisation Count 493
# Adding combi Count 494
# Adding marbles Count 495
# Adding transparency Count 496
# Adding linki Count 497
# Adding rapple Count 498
# Adding heuristic Count 499
# Adding pyramid Count 500
# Adding initialise Count 501
# Adding quantitative Count 502
# Adding quantitatively Count 503
# Adding elise Count 504
# Adding effecti Count 505
# Adding devaluation Count 506
# Adding distributions Count 507
# Adding flattens Count 508
# Adding slashdot Count 509
# Adding geeks Count 510
# Adding heuristics Count 511
# Adding lotus Count 512
# Adding crossvalidation Count 513
# Adding converges Count 514
# Adding clustered Count 515
# Adding crawl Count 516
# Adding wikipedia Count 517
# Adding dirichlet Count 518
# Adding gaussian Count 519
# Adding covariance Count 520
# Adding simplex Count 521
# Adding gaussians Count 522
# Adding labelli Count 523
# Adding unlabelled Count 524
# Adding initialisation Count 525
# Adding setups Count 526
# Adding cosine Count 527
# Adding unsupervisely Count 528
# Adding priori Count 529
# Adding marble Count 530
# Adding dissimilar Count 531
# Adding optimisable Count 532
# Adding iterative Count 533
# Adding blindly Count 534
# Adding hyperlinks Count 535
# Adding wellstructured Count 536
# Adding assignation Count 537
# Adding spreading Count 538
# Adding iterate Count 539
# Adding converge Count 540
# Adding unsupervised Count 541
# Adding trajectories Count 542
# Adding approximating Count 543
# Adding envelope Count 544
# Adding motlicek Count 545
# Adding bands Count 546
# Adding sinusoid Count 547
# Adding cosinusoid Count 548
# Adding sines Count 549
# Adding tragedy Count 550
# Adding predictor Count 551
# Adding modeling Count 552
# Adding prediction Count 553
# Adding icassp Count 554
# Adding kindergarten Count 555
# Adding peaks Count 556
# Adding cheju Count 557
# Adding islands Count 558
# Adding statistic Count 559
# Adding perceptual Count 560
# Adding perceptua Count 561
# Adding atlass Count 562
# Adding mathemat Count 563
# Adding theoretician Count 564
# Adding stanford Count 565
# Adding rigorous Count 566
# Adding regardi Count 567
# Adding icassps Count 568
# Adding marius Count 569
# Adding tremendously Count 570
# Adding hunger Count 571
# Adding timewise Count 572
# Adding compilation Count 573
# Adding herve Count 574
# Adding boyfriend Count 575
# Adding craziest Count 576
# Adding rewriting Count 577
# Adding livelihood Count 578
# Adding athineos Count 579
# Adding ellis Count 580
# Adding marios Count 581
# Adding inelegant Count 582
# Adding trajectory Count 583
# Adding graduated Count 584
# Adding barry Count 585
# Adding periodic Count 586
# Adding reverberance Count 587
# Adding unreadable Count 588
# Adding graduate Count 589
# Adding graduates Count 590
# Adding credits Count 591
# Adding subbands Count 592
# Adding trapezoidal Count 593
# Adding mfccs Count 594
# Adding triangulars Count 595
# Adding hilbert Count 596
# Adding autoregressive Count 597
# Adding logarithm Count 598
# Adding uncompress Count 599
# Adding interceptor Count 600
# Adding tandem Count 601
# Adding reconstructed Count 602
# Adding coefficients Count 603
# Adding compressions Count 604
# Adding resynthesis Count 605
# Adding residual Count 606
# Adding subband Count 607
# Adding confere Count 608
# Adding optimised Count 609
# Adding chernotsky Count 610
# Adding notepads Count 611
# Adding petra Count 612
# Adding hynek Count 613
# Adding bornet Count 614
# Adding quicknet Count 615
# Adding frontends Count 616
# Adding backend Count 617
# Adding preserved Count 618
# Adding preserving Count 619
# Adding rewrote Count 620
# Adding synchronize Count 621
# Adding sphinx Count 622
# Adding acquisition Count 623
# Adding reconstruct Count 624
# Adding classify Count 625
# Adding inference Count 626
# Adding matrices Count 627
# Adding midtech Count 628
# Adding installation Count 629
# Adding loudest Count 630
# Adding optic Count 631
# Adding icsla Count 632
# Adding sectors Count 633
# Adding socialising Count 634
# Adding pedagogical Count 635
# Adding visuali Count 636
# Adding visualising Count 637
# Adding disappearing Count 638
# Adding historically Count 639
# Adding exhale Count 640
# Adding extending Count 641
# Adding subprojects Count 642
# Adding localization Count 643
# Adding distributing Count 644
# Adding mirroring Count 645
# Adding electret Count 646
# Adding omnidirectional Count 647
# Adding selfregulating Count 648
# Adding normative Count 649
# Adding accesi Count 650
# Adding peripher Count 651
# Adding peripherical Count 652
# Adding distant Count 653
# Adding approximatively Count 654
# Adding solidity Count 655
# Adding richer Count 656
# Adding counterintuitive Count 657
# Adding radians Count 658
# Adding occupying Count 659
# Adding prolongating Count 660
# Adding inherent Count 661
# Adding intersect Count 662
# Adding dominant Count 663
# Adding instantaneous Count 664
# Adding negligible Count 665
# Adding timbre Count 666
# Adding francais Count 667
# Adding females Count 668
# Adding energetic Count 669
# Adding smoothing Count 670
# Adding stationary Count 671
# Adding asymmet Count 672
# Adding suboptimal Count 673
# Adding synchronised Count 674
# Adding elevation Count 675
# Adding triangulation Count 676
# Adding conversations Count 677
# Adding subtracting Count 678
# Adding interval Count 679
# Adding emotion Count 680
# Adding involvement Count 681
# Adding participating Count 682
# Adding localisation Count 683
# Adding spontaneous Count 684
# Adding adequately Count 685
# Adding stationality Count 686
# Adding plosives Count 687
# Adding modulation Count 688
# Adding nyquist Count 689
# Adding transitions Count 690
# Adding subwindows Count 691
# Adding leven Count 692
# Adding improvement Count 693
# Adding normalising Count 694
# Adding handful Count 695
# Adding framing Count 696
# Adding quoting Count 697
# Adding discreet Count 698
# Adding optimation Count 699
# Adding cautious Count 700
# Adding phoneticians Count 701
# Adding lvcsr Count 702
# Adding synthesise Count 703
# Adding synthes Count 704
# Adding synthesised Count 705
# Adding lagos Count 706
# Adding convulsed Count 707
# Adding entropies Count 708
# Adding aurora Count 709
# Adding icslp Count 710
# Adding publishing Count 711
# Adding chrystler Count 712
# Adding dragon Count 713
# Adding dictation Count 714
# Adding callings Count 715
# Adding festival Count 716
# Adding syntax Count 717
# Adding occas Count 718
# Adding concatenation Count 719
# Adding diphones Count 720
# Adding multisyn Count 721
# Adding viterbi Count 722
# Adding johann Count 723
# Adding semitied Count 724
# Adding decorrelation Count 725
# Adding diagonals Count 726
# Adding mixtures Count 727
# Adding megabytes Count 728
# Adding nonoptimal Count 729
# Adding nonoptimum Count 730
# Adding decompose Count 731
# Adding quantise Count 732
# Adding encoding Count 733
# Adding prett Count 734
# Adding singular Count 735
# Adding qualcomm Count 736
# Adding decorrelations Count 737
# Adding cohens Count 738
# Adding northwest Count 739
# Adding lisbon Count 740
# Adding wheelchair Count 741
# Adding indic Count 742
# Adding suisse Count 743
# Adding decorrelate Count 744
# Adding variabl Count 745
# Adding beambot Count 746
# Adding supposing Count 747
# Adding normaliser Count 748
# Adding equidistant Count 749
# Adding scientists Count 750
# Adding costa Count 751
# Adding caparica Count 752
# Adding pentium Count 753
# Adding river Count 754
# Adding comprehensible Count 755
# Adding diphone Count 756
# Adding chooses Count 757
# Adding synthetic Count 758
# Adding authors Count 759
# Adding douglas Count 760
# Adding adams Count 761
# Adding trams Count 762
# Adding pruning Count 763
# Adding eurospeech Count 764
# Adding subwindow Count 765
# Adding daimler Count 766
# Adding secretive Count 767
# Adding mercedes Count 768
# Adding cohen Count 769
# Adding jorda Count 770
# Adding implant Count 771
# Adding intrinsic Count 772
# Adding sinusoidal Count 773
# Adding reconstruction Count 774
# Adding susceptible Count 775
# Adding parameterizing Count 776
# Adding temporally Count 777
# Adding amplitudes Count 778
# Adding refitting Count 779
# Adding triband Count 780
# Adding lawyer Count 781
# Adding delilahs Count 782
# Adding compressing Count 783
# Adding interpolate Count 784
# Adding scalable Count 785
# Adding unwrapping Count 786
# Adding monotonically Count 787
# Adding unwrapped Count 788
# Adding conceivably Count 789
# Adding discontinuities Count 790
# Adding modulated Count 791
# Adding nonlinear Count 792
# Adding slices Count 793
# Adding distortion Count 794
# Adding unvoiced Count 795
# Adding bugger Count 796
# Adding parameterization Count 797
# Adding container Count 798
# Adding packetized Count 799
# Adding transi Count 800
# Adding bandwidths Count 801
# Adding optimization Count 802
# Adding parameterize Count 803
# Adding anglia Count 804
# Adding cambridge Count 805
# Adding mathematical Count 806
# Adding dispute Count 807
# Adding interpolation Count 808
# Adding scaled Count 809
# Adding huffmans Count 810
# Adding quantize Count 811
# Adding whispering Count 812
# Adding quantization Count 813
# Adding quantisation Count 814
# Adding harmonic Count 815
# Adding frequencys Count 816
# Adding modulations Count 817
# Adding autocorrelation Count 818
# Adding pseudo Count 819
# Adding severe Count 820
# Adding stringent Count 821
# Adding milner Count 822
# Adding etsai Count 823
# Adding fourier Count 824
# Adding kilobits Count 825
# Adding kilobyte Count 826
# Adding harmonics Count 827
# Adding transcs Count 828
# Adding approximated Count 829
# Adding optimized Count 830
# Adding impulses Count 831
# Adding magnitudes Count 832
# Adding whispered Count 833
# Adding voiceness Count 834
# Adding mores Count 835
# Adding unwrap Count 836
# Adding quantizing Count 837
# Adding harmonicity Count 838
# Adding reconstr Count 839
# Adding spectrograms Count 840
# Adding artifacts Count 841
# Adding thirteenth Count 842
# Adding resynthesize Count 843
# Adding franck Count 844
# Adding alexandre Count 845
# Adding synchron Count 846
# Adding tolerable Count 847
# Adding alignments Count 848
# Adding microsecond Count 849
# Adding nondiploma Count 850
# Adding disting Count 851
# Adding acquiring Count 852
# Adding snapshots Count 853
# Adding fribourg Count 854
# Adding slaves Count 855
# Adding ethernet Count 856
# Adding firefree Count 857
# Adding slave Count 858
# Adding tapes Count 859
# Adding inserter Count 860
# Adding serted Count 861
# Adding insertion Count 862
# Adding uncode Count 863
# Adding darren Count 864
# Adding grabber Count 865
# Adding synchroni Count 866
# Adding unknown Count 867
# Adding diploma Count 868
# Adding demos Count 869
# Adding acquisi Count 870
# Adding advancements Count 871
# Adding capturing Count 872
# Adding indico Count 873
# Adding amphitheatre Count 874
# Adding captured Count 875
# Adding reviewing Count 876
# Adding accusation Count 877
# Adding broadly Count 878
# Adding exigencies Count 879
# Adding summarization Count 880
# Adding appearances Count 881
# Adding someday Count 882
# Adding routing Count 883
# Adding nuance Count 884
# Adding believing Count 885
# Adding submitted Count 886
# Adding independence Count 887
# Adding rescoring Count 888
# Adding pearson Count 889
# Adding fluctuating Count 890
# Adding fluctuation Count 891
# Adding recognized Count 892
# Adding absence Count 893
# Adding frequence Count 894
# Adding disconnected Count 895
# Adding shortterm Count 896
# Adding disposition Count 897
# Adding preprepare Count 898
# Adding umyou Count 899
# Adding improves Count 900
# Adding measurable Count 901
# Adding respecting Count 902
# Adding phoneme Count 903
# Adding router Count 904
# Adding pragmatic Count 905
# Adding performanceyou Count 906
# Adding correspondence Count 907
# Adding dependency Count 908
# Adding fluctuations Count 909
# Adding distracted Count 910
# Adding foreseeable Count 911
# Adding unimodal Count 912
# Adding graphemic Count 913
# Adding presegment Count 914
# Adding headings Count 915
# Adding stylistic Count 916
# Adding promises Count 917
# Adding jeanyves Count 918
# Adding familiarise Count 919
# Adding impulsive Count 920
# Adding purposefully Count 921
# Adding multimodality Count 922
# Adding occupy Count 923
# Adding nondeterminist Count 924
# Adding telecoms Count 925
# Adding beeped Count 926
# Adding breathing Count 927
# Adding obstructed Count 928
# Adding extrapolate Count 929
# Adding aspectw Count 930
# Adding ohbut Count 931
# 932

# %%
word_phoneme_dict['funnier']
# Out:
# 'F AH N IY ER'

# %%
#save updated word phoneme dict
np.save("Data/word_phoneme_dict.npy", word_phoneme_dict)

# %% [markdown]
# End Of Training Cells

# %%
a = torch.tensor(np.array([1,2,3]))
b = torch.tensor(np.array([4,5,6]))
c = torch.utils.data.TensorDataset(a,b)
d = torch.utils.data.TensorDataset(a*10,b*10)

# %%
e = torch.utils.data.ConcatDataset((c,d))

# %%
f = torch.utils.data.DataLoader(e, batch_size = 1)

for x in f:
    print(x)
# Out:
# [tensor([1], dtype=torch.int32), tensor([4], dtype=torch.int32)]
# [tensor([2], dtype=torch.int32), tensor([5], dtype=torch.int32)]
# [tensor([3], dtype=torch.int32), tensor([6], dtype=torch.int32)]
# [tensor([10], dtype=torch.int32), tensor([40], dtype=torch.int32)]
# [tensor([20], dtype=torch.int32), tensor([50], dtype=torch.int32)]
# [tensor([30], dtype=torch.int32), tensor([60], dtype=torch.int32)]
