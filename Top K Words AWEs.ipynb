# %% [markdown]
# # Top K Word AWEs

# %% [markdown]
# Notebook to Train and Run Word Embeddings for the Top K most common words in the dataset

# %% [markdown]
# ## 1. Import Libraries

# %%
#Core Python, Pandas, and kaldi_io
import numpy as np
import pandas as pd
import string
from collections import Counter
import random
import kaldi_io

#Scikit
from sklearn import manifold
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import pairwise_distances,average_precision_score
from sklearn.metrics.pairwise import pairwise_kernels
from scipy import stats
from scipy.spatial.distance import pdist

#Plotting
from matplotlib import pyplot as plt
import seaborn as sns



#Torch and utilities
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset,DataLoader,random_split,ConcatDataset
import torch.cuda as cutorch

#Import User defined classes
from data_helpers import DataHelper
from models import SimpleNet, SiameseNet
from train_test_helpers import accuracy,evaluate_model,evaluate_model_paper,test_model,plot_learning_curves
from train_test_helpers import plot_learning_curves,siamese_train_loop,train_loop 

#datsets
from datasets import CNN_dataset, SiameseTriplets, Siamese_top_k, CNN_top_k
from datasets import BalancedBatchSampler,TopK_WordsSampler
# Out:
# ################################################################################
# ### WARNING, path does not exist: KALDI_ROOT=/mnt/matylda5/iveselyk/Tools/kaldi-trunk
# ###          (please add 'export KALDI_ROOT=<your_path>' in your $HOME/.profile)
# ###          (or run as: KALDI_ROOT=<your_path> python <your_script>.py)
# ################################################################################

# %% [markdown]
# ## 2. Train Models

# %% [markdown]
# Here we train various AWE models on these top k common words

# %%
#Define common training parameters
cuda = torch.cuda.is_available()
dev = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# ### 2.1 CNN Model

# %% [markdown]
# #Load Data
#
# #Dataset Parameters
# snr = np.Inf
# cluster = False
#
# #Datasets
# train_ds = AMI_dataset(split_set = "train", char_threshold = 5, frequency_bounds = (0,np.Inf), snr = snr, cluster = cluster)
# val_ds = AMI_dataset(split_set = "val", char_threshold = 5, frequency_bounds = (0,np.Inf), snr = snr, cluster = cluster)
# #test_ds = AMI_dataset(split_set = "test", char_threshold = 5, frequency_bounds = (0,np.Inf), snr = snr, cluster = False)

# %% [markdown]
# #Define Model and training Parameters
# num_output = len(train_ds.c.keys())
# #Defining training criterion
# criterion = nn.NLLLoss()
#
# #optimizer = optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
# num_epochs = 150
# batch_size = 64

# %% [markdown]
# #K values
# k_values = [100,500,1000,5000]
#
# #Loop over various values of k
# for k in k_values:
#
#     #Create the sampler
#     train_batch_sampler = TopK_WordsSampler(train_ds.labels, k = k, batch_size = batch_size)
#
#     #Dataloaders
#     kwargs = {'num_workers': 1, 'pin_memory': True} if cuda else {}
#     train_dl = torch.utils.data.DataLoader(train_ds, batch_sampler=train_batch_sampler, **kwargs)
#     val_dl = DataLoader(val_ds, batch_size=bs, pin_memory = True, shuffle = True, drop_last = True)
#
#
#     #Create Model
#     net = SimpleNet(num_output)
#     net = net.float()
#     net.to(dev)
#
#     #Optimizer
#     optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
#
#     #Unique save path
#     model_save_path = "./Models/cnn_top_%d_words.pth"%(k)
#     lc_save_path = "./Models/cnn_top_%d_words.png"%(k)
#
#     #Train the Model
#     hist = train_loop(net,num_epochs,train_dl,val_dl,optimizer,criterion,dev,save_path=model_save_path,verbose = True)
#
#     #Save learning curves
#     plot_learning_curves(hist,lc_save_path, show = False)

# %% [markdown]
# #Free memory from datasets
# del train_ds,val_ds,train_dl,val_dl,train_batch_sampler

# %% [markdown]
# ### 3.2 Siamese Model

# %%
#Defining training criterion

#optimizer = optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
num_epochs = 150
batch_size = 64

# %%
#K values
#k_values = [100,500,1000,5000]
k_values = [100]
#Dataset Parameters
snr = np.Inf
cluster = False

#Loop over various values of k
for k in k_values:
    
    train_ds = Siamese_top_k(k = k, split_set = "train", frequency_bounds = (0,np.Inf), snr = snr, cluster = cluster)
    val_ds = Siamese_top_k(k = k, split_set = "val", frequency_bounds = (0,np.Inf), snr = snr, cluster = cluster)


    #DataLoaders
    train_dl = DataLoader(train_ds, batch_size=batch_size, pin_memory = True, shuffle = True, drop_last = True)
    val_dl = DataLoader(val_ds, batch_size=batch_size, pin_memory = True, shuffle = True, drop_last = True)
    
    #Create Model
    net = SiameseNet()
    net = net.float()
    net.to(dev)
    
    #Optimizer
    optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
    
    #Unique save path
    model_save_path = "./Models/Vanilla_Siamese_top_%d_words.pth"%(k)
    lc_save_path = "./Models/Vanilla_Siamese_top_%d_words.png"%(k)
    
    #Train the Model
    hist = siamese_train_loop(net,num_epochs,train_dl,val_dl,optimizer,dev,save_path=model_save_path,verbose = True)
    
    #Save learning curves
    plot_learning_curves(hist,lc_save_path, show = False)
# Out:
# Length before filtering on char length 169383
# Length after filtering on char length 80821
# Finished Loading the Data, 80821 examples
# Number of Unique words  8607
# Length before filtering for top 100 words 80821
# Length after filtering for top 100 words 26971
# (16182, 40, 100) (5394, 40, 100) (5395, 40, 100)
# C:\Users\jayes\Downloads\LSV\acoustic_word_embeddings\datasets.py:379: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.data_class[self.word_to_num[key]] = torch.tensor(self.inputs[ids], dtype = torch.float).cpu()
# Triplet Shape
# torch.Size([1500, 3, 40, 100]) torch.Size([1500, 2])
# Length before filtering on char length 169383
# Length after filtering on char length 80821
# Finished Loading the Data, 80821 examples
# Number of Unique words  8607
# Length before filtering for top 100 words 80821
# Length after filtering for top 100 words 26971
# (16182, 40, 100) (5394, 40, 100) (5395, 40, 100)
# Triplet Shape
# torch.Size([1500, 3, 40, 100]) torch.Size([1500, 2])
# epoch 0
# Best val loss 0.141 Saving Model...
# train loss: 0.142
# val loss: 0.141
# epoch 1
# Best val loss 0.139 Saving Model...
# train loss: 0.139
# val loss: 0.139
# epoch 2
# Best val loss 0.135 Saving Model...
# train loss: 0.135
# val loss: 0.135
# epoch 3
# Best val loss 0.131 Saving Model...
# train loss: 0.131
# val loss: 0.131
# epoch 4
# Best val loss 0.127 Saving Model...
# train loss: 0.126
# val loss: 0.127
# epoch 5
# Best val loss 0.125 Saving Model...
# train loss: 0.121
# val loss: 0.125
# epoch 6
# Best val loss 0.121 Saving Model...
# train loss: 0.117
# val loss: 0.121
# epoch 7
# Best val loss 0.118 Saving Model...
# train loss: 0.114
# val loss: 0.118
# epoch 8
# Best val loss 0.116 Saving Model...
# train loss: 0.110
# val loss: 0.116
# epoch 9
# Best val loss 0.115 Saving Model...
# train loss: 0.107
# val loss: 0.115
# epoch 10
# Best val loss 0.113 Saving Model...
# train loss: 0.105
# val loss: 0.113
# epoch 11
# Best val loss 0.112 Saving Model...
# train loss: 0.102
# val loss: 0.112
# epoch 12
# Best val loss 0.110 Saving Model...
# train loss: 0.101
# val loss: 0.110
# epoch 13
# Best val loss 0.109 Saving Model...
# train loss: 0.098
# val loss: 0.109
# epoch 14
# Best val loss 0.108 Saving Model...
# train loss: 0.097
# val loss: 0.108
# epoch 15
# Best val loss 0.107 Saving Model...
# train loss: 0.095
# val loss: 0.107
# epoch 16
# train loss: 0.093
# val loss: 0.108
# epoch 17
# Best val loss 0.107 Saving Model...
# train loss: 0.092
# val loss: 0.107
# epoch 18
# Best val loss 0.107 Saving Model...
# train loss: 0.091
# val loss: 0.107
# epoch 19
# Best val loss 0.106 Saving Model...
# train loss: 0.089
# val loss: 0.106
# epoch 20
# train loss: 0.088
# val loss: 0.106
# epoch 21
# Best val loss 0.105 Saving Model...
# train loss: 0.087
# val loss: 0.105
# epoch 22
# Best val loss 0.105 Saving Model...
# train loss: 0.085
# val loss: 0.105
# epoch 23
# Best val loss 0.105 Saving Model...
# train loss: 0.085
# val loss: 0.105
# epoch 24
# Best val loss 0.104 Saving Model...
# train loss: 0.083
# val loss: 0.104
# epoch 25
# train loss: 0.082
# val loss: 0.105
# epoch 26
# train loss: 0.081
# val loss: 0.104
# epoch 27
# Best val loss 0.104 Saving Model...
# train loss: 0.079
# val loss: 0.104
# epoch 28
# train loss: 0.078
# val loss: 0.104
# epoch 29
# Best val loss 0.104 Saving Model...
# train loss: 0.077
# val loss: 0.104
# epoch 30
# Best val loss 0.103 Saving Model...
# train loss: 0.076
# val loss: 0.103
# epoch 31
# train loss: 0.075
# val loss: 0.103
# epoch 32
# train loss: 0.073
# val loss: 0.104
# epoch 33
# Best val loss 0.103 Saving Model...
# train loss: 0.072
# val loss: 0.103
# epoch 34
# train loss: 0.071
# val loss: 0.104
# epoch 35
# train loss: 0.070
# val loss: 0.104
# epoch 36
# Best val loss 0.102 Saving Model...
# train loss: 0.069
# val loss: 0.102
# epoch 37
# train loss: 0.067
# val loss: 0.103
# epoch 38
# train loss: 0.067
# val loss: 0.103
# epoch 39
# train loss: 0.066
# val loss: 0.104
# epoch 40
# train loss: 0.065
# val loss: 0.103
# epoch 41
# train loss: 0.064
# val loss: 0.103
# epoch 42
# train loss: 0.062
# val loss: 0.103
# epoch 43
# train loss: 0.062
# val loss: 0.103
# epoch 44
# train loss: 0.060
# val loss: 0.104
# epoch 45
# train loss: 0.060
# val loss: 0.104
# epoch 46
# Best val loss 0.102 Saving Model...
# train loss: 0.059
# val loss: 0.102
# epoch 47
# train loss: 0.057
# val loss: 0.103
# epoch 48
# train loss: 0.057
# val loss: 0.103
# epoch 49
# train loss: 0.055
# val loss: 0.103
# epoch 50
# train loss: 0.055
# val loss: 0.103
# epoch 51
# train loss: 0.054
# val loss: 0.103
# epoch 52
# train loss: 0.053
# val loss: 0.104
# epoch 53
# train loss: 0.052
# val loss: 0.103
# epoch 54
# train loss: 0.050
# val loss: 0.103
# epoch 55
# train loss: 0.050
# val loss: 0.103
# epoch 56
# train loss: 0.049
# val loss: 0.103
# epoch 57
# train loss: 0.049
# val loss: 0.104
# epoch 58
# train loss: 0.046
# val loss: 0.103
# epoch 59
# train loss: 0.046
# val loss: 0.104
# epoch 60
# train loss: 0.046
# val loss: 0.104
# epoch 61
# train loss: 0.044
# val loss: 0.103
# epoch 62
# train loss: 0.043
# val loss: 0.103
# epoch 63
# train loss: 0.043
# val loss: 0.103
# epoch 64
# train loss: 0.041
# val loss: 0.103
# epoch 65
# train loss: 0.040
# val loss: 0.103
# epoch 66
# train loss: 0.039
# val loss: 0.104
# epoch 67
# train loss: 0.038
# val loss: 0.104
# epoch 68
# train loss: 0.038
# val loss: 0.104
# epoch 69
# train loss: 0.037
# val loss: 0.104
# epoch 70
# train loss: 0.036
# val loss: 0.104
# epoch 71
# train loss: 0.034
# val loss: 0.104
# epoch 72
# train loss: 0.034
# val loss: 0.104
# epoch 73
# train loss: 0.034
# val loss: 0.104
# epoch 74
# train loss: 0.033
# val loss: 0.104
# epoch 75
# train loss: 0.032
# val loss: 0.104
# epoch 76
# train loss: 0.031
# val loss: 0.105
# epoch 77
# train loss: 0.030
# val loss: 0.104
# epoch 78
# train loss: 0.029
# val loss: 0.104
# epoch 79
# train loss: 0.029
# val loss: 0.104
# epoch 80
# train loss: 0.028
# val loss: 0.104
# epoch 81
# train loss: 0.027
# val loss: 0.104
# epoch 82
# train loss: 0.026
# val loss: 0.105
# epoch 83
# train loss: 0.026
# val loss: 0.105
# epoch 84
# train loss: 0.025
# val loss: 0.105
# epoch 85
# train loss: 0.024
# val loss: 0.105
# epoch 86
# train loss: 0.024
# val loss: 0.105
# epoch 87
# train loss: 0.023
# val loss: 0.105
# epoch 88
# train loss: 0.022
# val loss: 0.105
# epoch 89
# train loss: 0.021
# val loss: 0.105
# epoch 90
# train loss: 0.021
# val loss: 0.106
# epoch 91
# train loss: 0.020
# val loss: 0.105
# epoch 92
# train loss: 0.020
# val loss: 0.105
# epoch 93
# train loss: 0.019
# val loss: 0.105
# epoch 94
# train loss: 0.019
# val loss: 0.106
# epoch 95
# train loss: 0.018
# val loss: 0.105
# epoch 96
# train loss: 0.017
# val loss: 0.106
# epoch 97
# train loss: 0.017
# val loss: 0.106
# epoch 98
# train loss: 0.017
# val loss: 0.106
# epoch 99
# train loss: 0.016
# val loss: 0.106
# epoch 100
# train loss: 0.015
# val loss: 0.106
# epoch 101
# train loss: 0.015
# val loss: 0.106
# epoch 102
# train loss: 0.014
# val loss: 0.106
# epoch 103
# train loss: 0.014
# val loss: 0.107
# epoch 104
# train loss: 0.013
# val loss: 0.107
# epoch 105
# train loss: 0.013
# val loss: 0.106
# epoch 106
# train loss: 0.012
# val loss: 0.107
# epoch 107
# train loss: 0.012
# val loss: 0.107
# epoch 108
# train loss: 0.012
# val loss: 0.107
# epoch 109
# train loss: 0.011
# val loss: 0.107
# epoch 110
# train loss: 0.011
# val loss: 0.107
# epoch 111
# train loss: 0.010
# val loss: 0.107
# epoch 112
# train loss: 0.010
# val loss: 0.107
# epoch 113
# train loss: 0.010
# val loss: 0.106
# epoch 114
# train loss: 0.010
# val loss: 0.107
# epoch 115
# train loss: 0.009
# val loss: 0.107
# epoch 116
# train loss: 0.008
# val loss: 0.107
# epoch 117
# train loss: 0.008
# val loss: 0.107
# epoch 118
# train loss: 0.008
# val loss: 0.106
# epoch 119
# train loss: 0.008
# val loss: 0.107
# epoch 120
# train loss: 0.007
# val loss: 0.107
# epoch 121
# train loss: 0.006
# val loss: 0.108
# epoch 122
# train loss: 0.007
# val loss: 0.108
# epoch 123
# train loss: 0.007
# val loss: 0.108
# epoch 124
# train loss: 0.007
# val loss: 0.108
# epoch 125
# train loss: 0.006
# val loss: 0.108
# epoch 126
# train loss: 0.006
# val loss: 0.107
# epoch 127
# train loss: 0.005
# val loss: 0.108
# epoch 128
# train loss: 0.005
# val loss: 0.109
# epoch 129
# train loss: 0.005
# val loss: 0.108
# epoch 130
# train loss: 0.005
# val loss: 0.108
# epoch 131
# train loss: 0.004
# val loss: 0.109
# epoch 132
# train loss: 0.004
# val loss: 0.108
# epoch 133
# train loss: 0.004
# val loss: 0.108
# epoch 134
# train loss: 0.004
# val loss: 0.109
# epoch 135
# train loss: 0.004
# val loss: 0.109
# epoch 136
# train loss: 0.003
# val loss: 0.108
# epoch 137
# train loss: 0.003
# val loss: 0.109
# epoch 138
# train loss: 0.003
# val loss: 0.109
# epoch 139
# train loss: 0.003
# val loss: 0.109
# epoch 140
# train loss: 0.003
# val loss: 0.109
# epoch 141
# train loss: 0.002
# val loss: 0.109
# epoch 142
# train loss: 0.002
# val loss: 0.109
# epoch 143
# train loss: 0.002
# val loss: 0.109
# epoch 144
# train loss: 0.002
# val loss: 0.109
# epoch 145
# train loss: 0.002
# val loss: 0.109
# epoch 146
# train loss: 0.002
# val loss: 0.110
# epoch 147
# train loss: 0.002
# val loss: 0.109
# epoch 148
# train loss: 0.002
# val loss: 0.110
# epoch 149
# train loss: 0.002
# val loss: 0.109
# Finished Training

# %%
snr = np.Inf
cluster = False
train_ds = CNN_top_k(k = 100, split_set = "train", char_threshold = 5, frequency_bounds = (0,np.Inf), snr = snr, cluster = cluster)
# Out:
# Length before filtering on char length 169383
# Length after filtering on char length 80821
# Finished Loading the Data, 80821 examples
# Number of Unique words  8607
# Length before filtering for top 100 words 80821
# Length after filtering for top 100 words 26971
# (16182, 40, 100) (5394, 40, 100) (5395, 40, 100)

# %% [markdown]
# ### 3.3 Siamese Model with Triplet Mining

# %% [markdown]
# ## Visualize Results

# %%
a = ["word","blabla","l","a","l"]

b = np.array(a)

print(b)
# Out:
# ['word' 'blabla' 'l' 'a' 'l']

# %%
np.where(b == "l")[0]
# Out:
# array([2, 4], dtype=int64)

# %%
a = ""
