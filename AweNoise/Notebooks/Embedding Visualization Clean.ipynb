# %%
#Core Python, Pandas, and kaldi_io
import numpy as np
import pandas as pd
import string
from collections import Counter
import random
import kaldi_io

#Scikit
from sklearn import manifold
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import pairwise_distances,average_precision_score
from sklearn.metrics.pairwise import pairwise_kernels
from scipy import stats
from scipy.spatial.distance import pdist
from sklearn.decomposition import PCA

#Plotting
from matplotlib import pyplot as plt
import seaborn as sns



#Torch and utilities
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset,DataLoader,random_split,ConcatDataset
import torch.cuda as cutorch

#Import User defined classes
from data_helpers import DataHelper
from models import SimpleNet, SimpleNet_with_dropout 
from siamese_dataset import SiameseTriplets
from train_test_helpers import accuracy,train_model,evaluate_model,evaluate_model_paper,test_model,plot_learning_curves
from ami_clean_dataset import AMI_clean_dataset
from ami_noisy_dataset import AMI_noisy_dataset
# Out:
# ################################################################################
# ### WARNING, path does not exist: KALDI_ROOT=/mnt/matylda5/iveselyk/Tools/kaldi-trunk
# ###          (please add 'export KALDI_ROOT=<your_path>' in your $HOME/.profile)
# ###          (or run as: KALDI_ROOT=<your_path> python <your_script>.py)
# ################################################################################

# %%
num_examples = np.Inf
#Load Noisy Data
train_ds = AMI_clean_dataset(num_examples = num_examples, split_set = "train", data_filepath = "", char_threshold = 5, frequency_bounds = (0,np.Inf), cluster = False)
val_ds = AMI_clean_dataset(num_examples = num_examples, split_set = "val", data_filepath = "", char_threshold = 5, frequency_bounds = (0,np.Inf), cluster = False)
test_ds = AMI_clean_dataset(num_examples = num_examples, split_set = "test", data_filepath = "", char_threshold = 5, frequency_bounds = (0,np.Inf), cluster = False)
#DataLoaders
#train_dl = DataLoader(train_ds, batch_size=bs, pin_memory = True, shuffle = True, drop_last = True)
#val_dl = DataLoader(val_ds, batch_size=bs, pin_memory = True, shuffle = True, drop_last = True)
#test_dl = DataLoader(test_ds, batch_size=bs, pin_memory = True, shuffle = True, drop_last = True)
# Out:
# Length before filtering on char length 317927
# Length after filtering on char length 173657
# Length before filtering on frequency_bounds 173657
# Finished Loading the Data, 173657 examples
# Number of Unique words  9974
# torch.Size([104193, 40, 100]) torch.Size([34732, 40, 100]) torch.Size([34732, 40, 100])
# Length before filtering on char length 317927
# Length after filtering on char length 173657
# Length before filtering on frequency_bounds 173657
# Finished Loading the Data, 173657 examples
# Number of Unique words  9974
# torch.Size([104193, 40, 100]) torch.Size([34732, 40, 100]) torch.Size([34732, 40, 100])
# Length before filtering on char length 317927
# Length after filtering on char length 173657
# Length before filtering on frequency_bounds 173657
# Finished Loading the Data, 173657 examples
# Number of Unique words  9974
# torch.Size([104193, 40, 100]) torch.Size([34732, 40, 100]) torch.Size([34732, 40, 100])

# %%
word_to_num, num_to_word, c = train_ds.word_to_num, train_ds.num_to_word, train_ds.c

# %%
#Visualization Dataset and DataLoader
visualization_ds = torch.utils.data.ConcatDataset([train_ds,val_ds,test_ds])
visualization_dl = DataLoader(visualization_ds, batch_size=1024, pin_memory = True, drop_last = False)

# %%
dev = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
num_output = len(test_ds.c.keys())
dropout_probability = 0.5
model_save_path = "./Models/cnn_clean_dropout_%d.pth"%(int(dropout_probability*100))
#Create the Net and load weights
net = SimpleNet_with_dropout(num_output, p = dropout_probability)
net = net.float()
net.to(dev)
net.eval()
print("Loading Weights")
net.load_state_dict(torch.load(model_save_path))
# Out:
# Loading Weights
# <All keys matched successfully>

# %%
def nearest_neighbors(net,visualization_dl,n_neighbors = 3):
    
    embeddings = None
    labels = None
    
    for xb,yb in visualization_dl:
        #If device is GPU move features to GPU
        if dev.type == 'cuda' and not xb.is_cuda:
            xb = xb.to(dev, non_blocking=True)
            
        #Get the embeddings
        batch_embeddings = net(xb).cpu().detach().numpy()
        
        #Add to the main embeddings
        if embeddings is not None:
            embeddings = np.vstack((embeddings, batch_embeddings))
        else:
            embeddings = batch_embeddings
    
    nbrs = NearestNeighbors(n_neighbors=n_neighbors, algorithm='kd_tree',metric = 'euclidean', n_jobs = 4).fit(embeddings)
    distances,indices = nbrs.kneighbors(embeddings)
    
    return distances,indices

# %%
def nearest_neighbors_for_word_old(word,indices,labels):
    
    num_list = [word_to_num[word]]
    ids = np.where(np.isin(labels,np.array(num_list)))
    neighbor_indices = indices[ids]
    
    for i in range(neighbor_indices.shape[0]):
        neighboring_words = [num_to_word[labels[neighbor_indices[i,j]]] for j in range(neighbor_indices.shape[1])]
        print(neighboring_words)

# %%
def nearest_neighbors_for_word(word,indices,labels):
    
    num_list = [word_to_num[word]]
    ids = np.where(np.isin(labels,np.array(num_list)))
    neighbor_indices = indices[ids]
    
    for i in range(neighbor_indices.shape[0]):
        neighboring_words = [num_to_word[labels[neighbor_indices[i,j]]] for j in range(neighbor_indices.shape[1])]
        print(neighboring_words)

# %%
#distances,indices = nearest_neighbors(net,visualization_dl,n_neighbors = 3)

# %%
def give_tsne(net,visualization_dl, num_examples = 1024, do_pca = False):
    
    embeddings = None
    labels = None
    for i,(xb,yb) in enumerate(visualization_dl):
        #If device is GPU move features to GPU
        if dev.type == 'cuda' and not xb.is_cuda:
            xb = xb.to(dev, non_blocking=True)
        if embeddings is not None:
            print(embeddings.shape[0])
        
        
        
            
        #Get the embeddings
        batch_embeddings = net.give_embeddings(xb, dev)
        
        #Add to the main embeddings
        if embeddings is not None:
            embeddings = np.vstack((embeddings, batch_embeddings))
            labels = np.hstack((labels,yb))
        else:
            embeddings = batch_embeddings
            labels = yb
        
        if embeddings.shape[0] > num_examples:
            break
    
    #Do PCA
    if do_pca:
        pca = PCA(n_components=50)
        x = Pca.fit_transform(embeddings)
            
    tsne = manifold.TSNE(n_components=2, verbose=1, perplexity=40, n_iter=500)
    tsne_vectors = tsne.fit_transform(embeddings)
    
    return tsne_vectors, labels

# %%
def add_membership(word):
    train_tag = "Tr" if word in train_words else ""
    val_tag = "|Val" if word in val_words else ""
    test_tag = "|Ts" if word in test_words else ""
    return word+" (%s%s%s)"%(train_tag,val_tag,test_tag)

# %%
def visualize_words(word_list,tsne_vectors,labels,rigid_limits = False):
    #Get ids of words from labels
    num_list = [word_to_num[word] for word in word_list]
    ids = np.where(np.isin(labels,np.array(num_list)))
    
    df_subset = {}
    df_subset['tsne-2d-one'] = tsne_vectors[ids][:,0]
    df_subset['tsne-2d-two'] = tsne_vectors[ids][:,1]
    df_subset['Word'] = [num_to_word[labels[ids][i].item()] for i in range(ids[0].shape[0])]
    
    #Convert to dataframe
    df_subset = pd.DataFrame(df_subset)
    #Add membership tags
    #df_subset['Word'] = df_subset['Word'].apply(add_membership)
    
    #print(df_subset['tsne-2d-one'].shape)
    #print(df_subset['tsne-2d-two'].shape)
    #print(len(df_subset['y']))
    
    #print(ids)
    #print(df_subset['y'])
    
    g = sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="Word",
    data=df_subset,
    legend="full",
    alpha=0.5)
    g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
    
    if rigid_limits:
        x_coordinate = tsne_vectors[:,0]
        y_coordinate = tsne_vectors[:,1]
        epsilon = 5
        #plt.xlim(min(x_coordinate)-epsilon,max(x_coordinate)+epsilon)
        #plt.ylim(min(y_coordinate)-epsilon,max(y_coordinate)+epsilon)
        plt.xlim(-51-epsilon,46+epsilon)
        plt.ylim(-61-epsilon,44+epsilon)

# %%
tsne_vectors, labels = give_tsne(net,visualization_dl, num_examples = 2000, do_pca = False)
# Out:
# 1024
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2048 samples in 3.604s...
# [t-SNE] Computed neighbors for 2048 samples in 67.198s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2048
# [t-SNE] Computed conditional probabilities for sample 2000 / 2048
# [t-SNE] Computed conditional probabilities for sample 2048 / 2048
# [t-SNE] Mean sigma: 2.804707
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 116.929436
# [t-SNE] KL divergence after 500 iterations: 2.258080

# %%
#words = [num_to_word[labels[ids][i].item()]

# %%
words = [num_to_word[labels[i].item()] for i in range(labels.shape[0]) ]
word_counter = Counter(words)

# %%
word_counter.most_common()
# Out:
# [('thats', 25),
#  ('think', 23),
#  ('buttons', 19),
#  ('maybe', 17),
#  ('things', 16),
#  ('mmhmm', 16),
#  ('button', 13),
#  ('control', 13),
#  ('actually', 13),
#  ('people', 13),
#  ('right', 13),
#  ('something', 12),
#  ('because', 10),
#  ('there', 10),
#  ('three', 9),
#  ('little', 9),
#  ('remote', 9),
#  ('again', 9),
#  ('different', 9),
#  ('power', 8),
#  ('colours', 8),
#  ('colour', 8),
#  ('might', 8),
#  ('alright', 8),
#  ('product', 8),
#  ('rubber', 8),
#  ('meeting', 8),
#  ('probably', 8),
#  ('simple', 7),
#  ('interface', 7),
#  ('thing', 7),
#  ('battery', 7),
#  ('everything', 7),
#  ('doesnt', 7),
#  ('sorry', 7),
#  ('quite', 7),
#  ('should', 7),
#  ('looking', 6),
#  ('which', 6),
#  ('remotes', 6),
#  ('company', 6),
#  ('great', 6),
#  ('market', 6),
#  ('where', 6),
#  ('anything', 6),
#  ('these', 6),
#  ('better', 6),
#  ('suppose', 6),
#  ('pretty', 6),
#  ('thinking', 6),
#  ('still', 6),
#  ('fancy', 6),
#  ('point', 6),
#  ('whatever', 6),
#  ('exactly', 6),
#  ('could', 6),
#  ('always', 6),
#  ('yellow', 6),
#  ('dunno', 5),
#  ('speech', 5),
#  ('titanium', 5),
#  ('possible', 5),
#  ('start', 5),
#  ('controls', 5),
#  ('enough', 5),
#  ('every', 5),
#  ('extra', 5),
#  ('function', 5),
#  ('anyway', 5),
#  ('innovative', 5),
#  ('fruit', 5),
#  ('basically', 5),
#  ('project', 5),
#  ('about', 5),
#  ('havent', 5),
#  ('number', 5),
#  ('would', 5),
#  ('theres', 5),
#  ('cause', 5),
#  ('design', 5),
#  ('basic', 5),
#  ('thanks', 5),
#  ('material', 5),
#  ('press', 5),
#  ('those', 5),
#  ('volume', 5),
#  ('change', 5),
#  ('individual', 5),
#  ('discuss', 5),
#  ('really', 5),
#  ('screen', 5),
#  ('twenty', 5),
#  ('theory', 4),
#  ('black', 4),
#  ('shouldnt', 4),
#  ('slide', 4),
#  ('display', 4),
#  ('gonna', 4),
#  ('ideas', 4),
#  ('problem', 4),
#  ('recognition', 4),
#  ('double', 4),
#  ('earlier', 4),
#  ('circuit', 4),
#  ('sound', 4),
#  ('below', 4),
#  ('didnt', 4),
#  ('speaker', 4),
#  ('moment', 4),
#  ('outside', 4),
#  ('average', 4),
#  ('other', 4),
#  ('small', 4),
#  ('concept', 4),
#  ('going', 4),
#  ('example', 4),
#  ('functions', 4),
#  ('special', 4),
#  ('between', 4),
#  ('hundred', 4),
#  ('rather', 4),
#  ('channels', 4),
#  ('course', 4),
#  ('first', 4),
#  ('board', 4),
#  ('whats', 4),
#  ('meetings', 4),
#  ('marketing', 4),
#  ('wanna', 3),
#  ('relations', 3),
#  ('personal', 3),
#  ('working', 3),
#  ('kinda', 3),
#  ('found', 3),
#  ('inside', 3),
#  ('sends', 3),
#  ('possibly', 3),
#  ('terms', 3),
#  ('prototype', 3),
#  ('covers', 3),
#  ('phones', 3),
#  ('touch', 3),
#  ('gotta', 3),
#  ('thought', 3),
#  ('price', 3),
#  ('online', 3),
#  ('folder', 3),
#  ('bigger', 3),
#  ('numbers', 3),
#  ('sounds', 3),
#  ('device', 3),
#  ('minutes', 3),
#  ('sorta', 3),
#  ('important', 3),
#  ('close', 3),
#  ('technical', 3),
#  ('version', 3),
#  ('trying', 3),
#  ('depends', 3),
#  ('around', 3),
#  ('molds', 3),
#  ('guess', 3),
#  ('their', 3),
#  ('userfriendly', 3),
#  ('settings', 3),
#  ('another', 3),
#  ('watch', 3),
#  ('coffee', 3),
#  ('innovation', 3),
#  ('research', 3),
#  ('person', 3),
#  ('business', 3),
#  ('features', 3),
#  ('single', 3),
#  ('after', 3),
#  ('target', 3),
#  ('curve', 3),
#  ('impossible', 3),
#  ('difference', 3),
#  ('already', 3),
#  ('integrated', 3),
#  ('slogan', 3),
#  ('seven', 3),
#  ('report', 3),
#  ('using', 3),
#  ('learning', 3),
#  ('usual', 3),
#  ('twelve', 3),
#  ('stuff', 3),
#  ('fifty', 3),
#  ('fashion', 3),
#  ('interesting', 3),
#  ('everyone', 3),
#  ('standard', 3),
#  ('almost', 3),
#  ('thirty', 3),
#  ('difficult', 3),
#  ('presentation', 3),
#  ('shape', 3),
#  ('doing', 3),
#  ('costs', 3),
#  ('theyre', 3),
#  ('seventy', 3),
#  ('banana', 3),
#  ('findings', 2),
#  ('mouse', 2),
#  ('scrollwheel', 2),
#  ('changing', 2),
#  ('easier', 2),
#  ('couple', 2),
#  ('being', 2),
#  ('comfortable', 2),
#  ('segments', 2),
#  ('curved', 2),
#  ('handy', 2),
#  ('absorption', 2),
#  ('asked', 2),
#  ('continue', 2),
#  ('minute', 2),
#  ('automatically', 2),
#  ('question', 2),
#  ('source', 2),
#  ('youre', 2),
#  ('introduction', 2),
#  ('digital', 2),
#  ('bright', 2),
#  ('useless', 2),
#  ('original', 2),
#  ('information', 2),
#  ('chief', 2),
#  ('mobile', 2),
#  ('looks', 2),
#  ('totally', 2),
#  ('friendly', 2),
#  ('document', 2),
#  ('products', 2),
#  ('signal', 2),
#  ('access', 2),
#  ('files', 2),
#  ('technology', 2),
#  ('round', 2),
#  ('white', 2),
#  ('gimmick', 2),
#  ('problems', 2),
#  ('middle', 2),
#  ('informative', 2),
#  ('please', 2),
#  ('eight', 2),
#  ('opinion', 2),
#  ('infrared', 2),
#  ('teletext', 2),
#  ('playing', 2),
#  ('straight', 2),
#  ('remember', 2),
#  ('everybody', 2),
#  ('never', 2),
#  ('requires', 2),
#  ('having', 2),
#  ('marked', 2),
#  ('image', 2),
#  ('fruits', 2),
#  ('machine', 2),
#  ('available', 2),
#  ('projects', 2),
#  ('camtasia', 2),
#  ('results', 2),
#  ('linked', 2),
#  ('option', 2),
#  ('verbal', 2),
#  ('browser', 2),
#  ('specific', 2),
#  ('solution', 2),
#  ('needs', 2),
#  ('young', 2),
#  ('general', 2),
#  ('ready', 2),
#  ('issue', 2),
#  ('suggest', 2),
#  ('somewhere', 2),
#  ('decisions', 2),
#  ('called', 2),
#  ('plastic', 2),
#  ('apple', 2),
#  ('bottom', 2),
#  ('sides', 2),
#  ('creativity', 2),
#  ('presentations', 2),
#  ('actual', 2),
#  ('writing', 2),
#  ('corpus', 2),
#  ('agreed', 2),
#  ('today', 2),
#  ('equal', 2),
#  ('wouldnt', 2),
#  ('since', 2),
#  ('separate', 2),
#  ('together', 2),
#  ('rechargeable', 2),
#  ('often', 2),
#  ('galaxy', 2),
#  ('thatll', 2),
#  ('selling', 2),
#  ('instead', 2),
#  ('though', 2),
#  ('makes', 2),
#  ('recently', 2),
#  ('external', 2),
#  ('possibility', 2),
#  ('combine', 2),
#  ('shell', 2),
#  ('trends', 2),
#  ('initial', 2),
#  ('either', 2),
#  ('production', 2),
#  ('experience', 2),
#  ('afternoon', 2),
#  ('perfect', 2),
#  ('options', 2),
#  ('station', 2),
#  ('evaluation', 2),
#  ('build', 2),
#  ('speak', 2),
#  ('frequently', 2),
#  ('excuse', 2),
#  ('record', 2),
#  ('fairly', 2),
#  ('stick', 2),
#  ('choice', 2),
#  ('fronts', 2),
#  ('functional', 2),
#  ('channel', 2),
#  ('finger', 2),
#  ('weeks', 2),
#  ('forty', 2),
#  ('euros', 2),
#  ('reach', 2),
#  ('cells', 2),
#  ('eighteen', 2),
#  ('million', 2),
#  ('structure', 2),
#  ('system', 2),
#  ('final', 2),
#  ('zapping', 2),
#  ('understand', 2),
#  ('light', 2),
#  ('criteria', 2),
#  ('morning', 2),
#  ('video', 2),
#  ('docking', 2),
#  ('specified', 1),
#  ('rabbit', 1),
#  ('programmes', 1),
#  ('uhhuh', 1),
#  ('place', 1),
#  ('proper', 1),
#  ('worst', 1),
#  ('overall', 1),
#  ('hyperlink', 1),
#  ('badger', 1),
#  ('analyses', 1),
#  ('protect', 1),
#  ('bursting', 1),
#  ('preferences', 1),
#  ('assumed', 1),
#  ('adjusting', 1),
#  ('reasonable', 1),
#  ('largest', 1),
#  ('fields', 1),
#  ('poster', 1),
#  ('confusing', 1),
#  ('laptops', 1),
#  ('along', 1),
#  ('taking', 1),
#  ('tends', 1),
#  ('offers', 1),
#  ('killing', 1),
#  ('recycled', 1),
#  ('balls', 1),
#  ('directory', 1),
#  ('providing', 1),
#  ('bling', 1),
#  ('building', 1),
#  ('achieve', 1),
#  ('second', 1),
#  ('summarisation', 1),
#  ('follow', 1),
#  ('percentage', 1),
#  ('audio', 1),
#  ('interaction', 1),
#  ('sheep', 1),
#  ('traces', 1),
#  ('check', 1),
#  ('distinguish', 1),
#  ('eraser', 1),
#  ('krista', 1),
#  ('worry', 1),
#  ('within', 1),
#  ('definitely', 1),
#  ('panther', 1),
#  ('charges', 1),
#  ('dynamo', 1),
#  ('recharged', 1),
#  ('summary', 1),
#  ('naive', 1),
#  ('persons', 1),
#  ('stupid', 1),
#  ('languages', 1),
#  ('present', 1),
#  ('vertical', 1),
#  ('cutting', 1),
#  ('exchange', 1),
#  ('emails', 1),
#  ('existing', 1),
#  ('connect', 1),
#  ('break', 1),
#  ('sided', 1),
#  ('algorithm', 1),
#  ('laptop', 1),
#  ('kinetic', 1),
#  ('whole', 1),
#  ('everybodys', 1),
#  ('flashy', 1),
#  ('ninety', 1),
#  ('charger', 1),
#  ('responses', 1),
#  ('saying', 1),
#  ('local', 1),
#  ('versus', 1),
#  ('skimming', 1),
#  ('mockups', 1),
#  ('coming', 1),
#  ('store', 1),
#  ('characters', 1),
#  ('across', 1),
#  ('admit', 1),
#  ('curves', 1),
#  ('margin', 1),
#  ('benjo', 1),
#  ('clumsy', 1),
#  ('prefilter', 1),
#  ('galaxies', 1),
#  ('understanding', 1),
#  ('reactions', 1),
#  ('leader', 1),
#  ('opposed', 1),
#  ('quickly', 1),
#  ('matter', 1),
#  ('cover', 1),
#  ('advised', 1),
#  ('onehanded', 1),
#  ('perhaps', 1),
#  ('television', 1),
#  ('benefits', 1),
#  ('overcome', 1),
#  ('etcetera', 1),
#  ('compared', 1),
#  ('difficulty', 1),
#  ('dimensions', 1),
#  ('checking', 1),
#  ('glasses', 1),
#  ('resolve', 1),
#  ('characterisation', 1),
#  ('built', 1),
#  ('spectral', 1),
#  ('fixations', 1),
#  ('phone', 1),
#  ('broad', 1),
#  ('profit', 1),
#  ('fashionable', 1),
#  ('facility', 1),
#  ('ninja', 1),
#  ('added', 1),
#  ('elegant', 1),
#  ('vowel', 1),
#  ('benefit', 1),
#  ('democratically', 1),
#  ('approach', 1),
#  ('feature', 1),
#  ('speaking', 1),
#  ('basics', 1),
#  ('elsewhere', 1),
#  ('scroll', 1),
#  ('pause', 1),
#  ('description', 1),
#  ('common', 1),
#  ('species', 1),
#  ('towards', 1),
#  ('receive', 1),
#  ('watches', 1),
#  ('transform', 1),
#  ('anybodys', 1),
#  ('strokes', 1),
#  ('handed', 1),
#  ('eighty', 1),
#  ('argue', 1),
#  ('environment', 1),
#  ('layout', 1),
#  ('coarse', 1),
#  ('trend', 1),
#  ('complaints', 1),
#  ('fully', 1),
#  ('loaded', 1),
#  ('construct', 1),
#  ('sometimes', 1),
#  ('means', 1),
#  ('submenu', 1),
#  ('instance', 1),
#  ('segmenting', 1),
#  ('appearing', 1),
#  ('visible', 1),
#  ('divided', 1),
#  ('newest', 1),
#  ('phase', 1),
#  ('guillaume', 1),
#  ('alarm', 1),
#  ('sensors', 1),
#  ('doodling', 1),
#  ('rooms', 1),
#  ('checked', 1),
#  ('snapshot', 1),
#  ('favourite', 1),
#  ('months', 1),
#  ('setting', 1),
#  ('explanation', 1),
#  ('especially', 1),
#  ('sounded', 1),
#  ('requirements', 1),
#  ('specify', 1),
#  ('loads', 1),
#  ('streamlined', 1),
#  ('smart', 1),
#  ('english', 1),
#  ('exchanges', 1),
#  ('detailed', 1),
#  ('beeps', 1),
#  ('digit', 1),
#  ('sports', 1),
#  ('package', 1),
#  ('focussing', 1),
#  ('informatics', 1),
#  ('grapes', 1),
#  ('technologically', 1),
#  ('manager', 1),
#  ('sleek', 1),
#  ('heather', 1),
#  ('official', 1),
#  ('correction', 1),
#  ('financial', 1),
#  ('communication', 1),
#  ('explain', 1),
#  ('components', 1),
#  ('autism', 1),
#  ('discontinuity', 1),
#  ('short', 1),
#  ('physical', 1),
#  ('solar', 1),
#  ('aspects', 1),
#  ('queue', 1),
#  ('implement', 1),
#  ('complicated', 1),
#  ('supposed', 1),
#  ('spongy', 1),
#  ('fruitful', 1),
#  ('accessible', 1),
#  ('pictures', 1),
#  ('times', 1),
#  ('preprocessing', 1),
#  ('legos', 1),
#  ('stated', 1),
#  ('innovativeness', 1),
#  ('included', 1),
#  ('centr', 1),
#  ('usertested', 1),
#  ('hours', 1),
#  ('adjust', 1),
#  ('covered', 1),
#  ('independent', 1),
#  ('incorporating', 1),
#  ('goodlooking', 1),
#  ('sensible', 1),
#  ('allocation', 1),
#  ('applications', 1),
#  ('presuming', 1),
#  ('users', 1),
#  ('sensor', 1),
#  ('sammy', 1),
#  ('appealing', 1),
#  ('accomplish', 1),
#  ('programming', 1),
#  ('rubbers', 1),
#  ('layer', 1),
#  ('keypad', 1),
#  ('heavy', 1),
#  ('aspect', 1),
#  ('changes', 1),
#  ('words', 1),
#  ('situation', 1),
#  ('accordingly', 1),
#  ('prevents', 1),
#  ('third', 1),
#  ('flush', 1),
#  ('individually', 1),
#  ('colourful', 1),
#  ('fruity', 1),
#  ('considering', 1),
#  ('refrigerator', 1),
#  ('unlikely', 1),
#  ('reviewed', 1),
#  ('starts', 1),
#  ('voices', 1),
#  ('consuming', 1),
#  ('array', 1),
#  ('exist', 1),
#  ('direction', 1),
#  ('mango', 1),
#  ('heres', 1),
#  ('units', 1),
#  ('printed', 1),
#  ('recommendation', 1),
#  ('write', 1),
#  ('apart', 1),
#  ('topic', 1),
#  ('incentive', 1),
#  ('easiest', 1),
#  ('upset', 1),
#  ('technologies', 1),
#  ('consensus', 1),
#  ('consume', 1),
#  ('component', 1),
#  ('certainly', 1),
#  ('participant', 1),
#  ('decide', 1),
#  ('boards', 1),
#  ('pointing', 1),
#  ('lastly', 1),
#  ('loyal', 1),
#  ('minority', 1),
#  ('selfdestruct', 1),
#  ('thoughts', 1),
#  ('controller', 1),
#  ('editi', 1),
#  ('measure', 1),
#  ('directly', 1),
#  ('survey', 1),
#  ('recording', 1),
#  ('easily', 1),
#  ('understood', 1),
#  ('similar', 1),
#  ('manny', 1),
#  ('screens', 1),
#  ('requir', 1),
#  ('finish', 1),
#  ('entirely', 1),
#  ('closest', 1),
#  ('threshold', 1),
#  ('misplaced', 1),
#  ('touched', 1),
#  ('hydrogen', 1),
#  ('budget', 1),
#  ('piece', 1),
#  ('bullet', 1),
#  ('throw', 1),
#  ('cloud', 1),
#  ('relaxing', 1),
#  ('fairs', 1),
#  ('discourse', 1),
#  ('duplication', 1),
#  ('nicest', 1),
#  ('essentials', 1),
#  ('utterances', 1),
#  ('choose', 1),
#  ('steph', 1),
#  ('events', 1),
#  ('proposing', 1),
#  ('processing', 1),
#  ('effort', 1),
#  ('concludes', 1),
#  ('emission', 1),
#  ('require', 1),
#  ('african', 1),
#  ('ourselves', 1),
#  ('shown', 1),
#  ('noninteractive', 1),
#  ('summarised', 1),
#  ('window', 1),
#  ('specifically', 1),
#  ('strangely', 1),
#  ('sixteen', 1),
#  ('engineer', 1),
#  ('utterance', 1),
#  ('depending', 1),
#  ('pages', 1),
#  ('email', 1),
#  ('popular', 1),
#  ('batteries', 1),
#  ('consumerism', 1),
#  ('amplitude', 1),
#  ('finished', 1),
#  ('whenever', 1),
#  ('alone', 1),
#  ('result', 1),
#  ('shaped', 1),
#  ('multiple', 1),
#  ('relevant', 1),
#  ('therell', 1),
#  ('feeding', 1),
#  ('drawing', 1),
#  ('redundant', 1),
#  ('excellent', 1),
#  ('position', 1),
#  ('tiger', 1),
#  ('tripping', 1),
#  ('invent', 1),
#  ('silver', 1),
#  ('sorts', 1),
#  ('abbie', 1),
#  ('pointless', 1),
#  ('rerate', 1),
#  ('designs', 1),
#  ('furthermore', 1),
#  ('propose', 1),
#  ('search', 1),
#  ('roughly', 1),
#  ('software', 1),
#  ('further', 1),
#  ('therefore', 1),
#  ('mobiles', 1),
#  ('creaky', 1),
#  ('happens', 1),
#  ('table', 1),
#  ('evaluate', 1),
#  ('clear', 1),
#  ('hubble', 1),
#  ('score', 1),
#  ('frequency', 1),
#  ('normally', 1),
#  ('barbara', 1),
#  ('opportunity', 1),
#  ('increase', 1),
#  ('clearly', 1),
#  ('hasnt', 1),
#  ('arrange', 1),
#  ('commission', 1),
#  ('creative', 1),
#  ('necessarily', 1),
#  ('relating', 1),
#  ('obvious', 1),
#  ('fabrics', 1),
#  ('sense', 1),
#  ('consumers', 1),
#  ('clarify', 1),
#  ('spiders', 1),
#  ('works', 1),
#  ('model', 1),
#  ('development', 1),
#  ('highest', 1),
#  ('anyone', 1),
#  ('obviously', 1),
#  ('packages', 1),
#  ('stress', 1),
#  ('customdesigned', 1),
#  ('unique', 1),
#  ('internet', 1),
#  ('method', 1),
#  ('hoping', 1),
#  ('wasnt', 1),
#  ('ranked', 1),
#  ('background', 1),
#  ('leave', 1),
#  ('pushbutton', 1),
#  ('wheres', 1),
#  ('phases', 1),
#  ('explaining', 1),
#  ('resistance', 1),
#  ('creates', 1),
#  ('folded', 1),
#  ('afraid', 1),
#  ('algorithmic', 1),
#  ('certain', 1),
#  ('competitor', 1),
#  ('range', 1),
#  ('scrollwheels', 1),
#  ('manufacturing', 1),
#  ('personally', 1),
#  ('shame', 1),
#  ('chargeable', 1),
#  ('positions', 1),
#  ('talked', 1),
#  ('pushing', 1),
#  ('include', 1),
#  ('motif', 1),
#  ('parts', 1),
#  ('harder', 1),
#  ('booklet', 1),
#  ('wooden', 1),
#  ('risky', 1),
#  ('disadvantages', 1),
#  ('username', 1),
#  ('stage', 1),
#  ('useful', 1),
#  ('answer', 1),
#  ('semantics', 1),
#  ('addressing', 1),
#  ('electronics', 1),
#  ('print', 1),
#  ('combined', 1),
#  ('expensive', 1),
#  ('sleeping', 1),
#  ('least', 1),
#  ('wheel', 1),
#  ('vegetables', 1),
#  ('statistical', 1),
#  ('vegetable', 1),
#  ('train', 1),
#  ('fourth', 1),
#  ('voting', 1),
#  ('happening', 1),
#  ('dialogue', 1),
#  ('radio', 1),
#  ('woulda', 1),
#  ('batterys', 1),
#  ('attended', 1),
#  ('materials', 1),
#  ('datas', 1),
#  ('verbmobil', 1),
#  ('ionized', 1),
#  ('charge', 1),
#  ('until', 1),
#  ('kidding', 1),
#  ('missed', 1),
#  ('wondering', 1),
#  ('creating', 1),
#  ('scratched', 1),
#  ('lights', 1),
#  ('designer', 1),
#  ('kidney', 1),
#  ('leadership', 1),
#  ('energy', 1),
#  ('watching', 1),
#  ('optimistic', 1),
#  ('early', 1),
#  ('recent', 1),
#  ('retrieval', 1),
#  ('telephone', 1),
#  ('signalling', 1),
#  ('brand', 1),
#  ('reasons', 1),
#  ('magnitude', 1),
#  ('complete', 1),
#  ('resistant', 1),
#  ('fibre', 1),
#  ('themselves', 1),
#  ('supplement', 1),
#  ('capacity', 1),
#  ('movie', 1),
#  ('without', 1),
#  ('sliders', 1),
#  ('recognisable', 1),
#  ('briefly', 1),
#  ('looked', 1),
#  ('details', 1),
#  ('itself', 1),
#  ('smelly', 1),
#  ('lefthanded', 1),
#  ('taller', 1),
#  ('likes', 1),
#  ('based', 1),
#  ('someone', 1),
#  ('under', 1),
#  ('pasting', 1),
#  ('smaller', 1),
#  ('simply', 1),
#  ('slight', 1),
#  ('erase', 1),
#  ('longlife', 1),
#  ('starting', 1),
#  ('emitting', 1),
#  ('afterwards', 1),
#  ('convention', 1),
#  ('pasted', 1),
#  ('careful', 1),
#  ('random', 1),
#  ('nothing', 1),
#  ('eliminate', 1),
#  ('prints', 1),
#  ('fanciness', 1),
#  ('heavier', 1),
#  ('square', 1),
#  ('cannot', 1),
#  ('instructions', 1),
#  ('transmitting', 1),
#  ('provide', 1),
#  ('welcome', 1),
#  ('training', 1),
#  ('snakes', 1),
#  ('finder', 1),
#  ('satisfied', 1),
#  ('sometime', 1),
#  ('operated', 1),
#  ('states', 1),
#  ('dialogues', 1),
#  ('capacitor', 1),
#  ('given', 1),
#  ('criterium', 1),
#  ('outdated', 1),
#  ('influences', 1),
#  ('variable', 1),
#  ('primary', 1),
#  ('activated', 1),
#  ('learn', 1),
#  ('started', 1),
#  ('distance', 1),
#  ('whiteboard', 1),
#  ('getting', 1),
#  ('sharpness', 1),
#  ('goodness', 1),
#  ('longer', 1),
#  ('yourself', 1),
#  ('electronic', 1),
#  ('thick', 1),
#  ('generate', 1),
#  ('nerves', 1),
#  ('needed', 1),
#  ('interchangeable', 1),
#  ('nicer', 1),
#  ('slightly', 1),
#  ('graphics', 1),
#  ('disaster', 1),
#  ('softer', 1),
#  ('track', 1),
#  ('suggested', 1),
#  ('grandmothers', 1),
#  ('hidden', 1),
#  ('reason', 1),
#  ('snout', 1),
#  ('mentioned', 1),
#  ('expertise', 1),
#  ('region', 1),
#  ('segmentation', 1),
#  ('industrial', 1),
#  ('featured', 1),
#  ('shifts', 1),
#  ('articulated', 1),
#  ('distinctions', 1),
#  ('powerpoints', 1),
#  ('according', 1),
#  ('takes', 1),
#  ('develop', 1),
#  ('inspiration', 1),
#  ('consider', 1),
#  ('tough', 1),
#  ('wallet', 1),
#  ('triangle', 1),
#  ('order', 1),
#  ('oughta', 1),
#  ('william', 1),
#  ('actions', 1),
#  ('werent', 1),
#  ('believe', 1),
#  ('dumped', 1),
#  ('suggestion', 1),
#  ('british', 1),
#  ('candidates', 1),
#  ('monday', 1),
#  ('produce', 1),
#  ('annoying', 1),
#  ('betwe', 1),
#  ('someones', 1),
#  ('discover', 1),
#  ('degree', 1),
#  ('screenshots', 1),
#  ('responsibility', 1),
#  ('stand', 1),
#  ('averages', 1),
#  ('antek', 1),
#  ('reduce', 1),
#  ('greater', 1),
#  ('thumb', 1),
#  ('whereas', 1),
#  ('relational', 1),
#  ('twice', 1),
#  ('preprocessed', 1),
#  ('suddenly', 1),
#  ('messenger', 1),
#  ('disorganized', 1),
#  ('quarters', 1),
#  ('strange', 1),
#  ('intuition', 1),
#  ('theirs', 1),
#  ('abundance', 1),
#  ('initially', 1),
#  ('fluxes', 1),
#  ('anyways', 1),
#  ('threes', 1),
#  ('numeric', 1),
#  ('degradation', 1),
#  ('fancier', 1),
#  ('projecting', 1),
#  ('trivial', 1),
#  ('animal', 1),
#  ...]

# %%
x_coordinate = tsne_vectors[:,0]
y_coordinate = tsne_vectors[:,1]
epsilon = 5
print(min(x_coordinate)-epsilon,max(x_coordinate)+epsilon)
print(min(y_coordinate)-epsilon,max(y_coordinate)+epsilon)
# Out:
# -45.392242431640625 46.82533264160156
# -61.67488479614258 44.5234489440918

# %%
word_list = ["mmhmm", "buttons", "control", "design", "recognition"]
visualize_words(word_list,tsne_vectors,labels, rigid_limits = True)

# %%
word_list = ["DEALERS","DEALS","BACK"]
visualize_words(word_list,tsne_vectors,labels,True)

# %%
word_list = ["ACCEPTED","ACCEPTS","RADIO","RAIDER","OWNER","OWNERS"]
visualize_words(word_list,tsne_vectors,labels,True)

# %%
word_list = ["NINE","NINETY","ACCEPTED","ACCEPTS","AIMED","AIMING"]
visualize_words(word_list,tsne_vectors,labels,True)

# %%
word_list = ["COUNT","COUNTS","SALE","SUPPORT","SUPPORTED"]
visualize_words(word_list,tsne_vectors,labels,True)

# %%
word_list = ["LATER","LATEST","CLOSE","CLOSING","CLOSED","CLOSELY"]
visualize_words(word_list,tsne_vectors,labels,True)

# %%
distances,indices = nearest_neighbors(net,torch.tensor(inputs,dtype=torch.float),labels,n_neighbors=5)

# %%
word = "SUPPORT"
nearest_neighbors_for_word(word,indices,labels)
# Out:
# ['SUPPORT', 'CLIMB', 'PROBABLY', 'AIRCRAFT', 'DIRECT']
# ['SUPPORT', 'OPERATOR', 'AIRCRAFT', 'HOLDING', 'SHARES']
# ['LIKELY', 'COMING', 'OPERATOR', 'SHARES', 'SURPRISE']

# %%
word = "LATER"
nearest_neighbors_for_word(word,indices,labels)
# Out:
# ['LATER', 'UNDER', 'HUNDRED', 'UNDER', 'HUNDRED']

# %%
word = "CLOSING"
nearest_neighbors_for_word(word,indices,labels)
# Out:
# ['CLOSING', 'WASHINGTON', 'AFTER', 'OPPOSITION', 'COMMENT']

# %%
word = "ACCEPTED"
nearest_neighbors_for_word(word,indices,labels)
# Out:
# ['ACCEPTED', 'INFLATION', 'PURCHASES', 'PROCESS', 'SPLIT']

# %%
word = "DEALS"
nearest_neighbors_for_word(word,indices,labels)
# Out:
# ['DEALS', 'PUBLICLY', 'FINANCIAL', 'FINANCIAL', 'EXPOSURE']

# %%
word = "ACCEPTS"
nearest_neighbors_for_word(word,indices,labels)
# Out:
# ['ACCEPTS', 'SIX', 'BUSINESS', 'SIX', 'SINCE']

# %%
word = "DAY"
nearest_neighbors_for_word(word,indices,labels)
# Out:
# ['DAY', 'MAY', 'MAY', 'MAY', 'EIGHT']
# ['DAY', 'BIDS', 'MAY', 'DAY', 'BASED']
# ['DAY', 'DAY', 'MAY', 'BIDS', 'BASED']
# ['DAY', 'YOU', 'HUNDRED', 'UNDER', 'CLEAR']

# %%
word = "DEALERS"
nearest_neighbors_for_word(word,indices,labels)
# Out:
# ['DEALERS', 'LANGUAGE', 'GROUP', 'TOO', 'PREVIOUS']
