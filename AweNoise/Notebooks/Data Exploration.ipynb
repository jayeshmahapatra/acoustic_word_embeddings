# %%
#Core Python, Pandas, and kaldi_io
import numpy as np
import pandas as pd
import string
from collections import Counter
import kaldi_io

#Scikit
from sklearn import manifold
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import pairwise_distances,average_precision_score
from sklearn.metrics.pairwise import pairwise_kernels
from scipy import stats

#Plotting
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.spatial.distance import pdist


#Torch and utilities
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset,DataLoader,random_split,ConcatDataset

from data_helpers import DataHelper
# Out:
# ################################################################################
# ### WARNING, path does not exist: KALDI_ROOT=/mnt/matylda5/iveselyk/Tools/kaldi-trunk
# ###          (please add 'export KALDI_ROOT=<your_path>' in your $HOME/.profile)
# ###          (or run as: KALDI_ROOT=<your_path> python <your_script>.py)
# ################################################################################

# %% [markdown]
# Stats of the MuliView Trainset

# %%
filepath = "Data/multi_view/trainset.list"

# %%
count = 0
words = []
with open(filepath) as fp:
    lines = fp.readlines()
    for line in lines: 
        count += 1
        #print("Line{}: {}".format(count, line.strip()))
        word = line.strip().split("_")[0]
        #print(word)
        words.append(word)

# %%
w = Counter(words)

# %%
print("Number of Examples {}".format(len(words)))
print("Number of Unique Words {}".format(len(w.keys())))
print("Maximum frequency {}".format(max(w.values())))
print("Minimum frequency {}".format(min(w.values())))
print("Maximum Character Length {}".format(max(list(map(len,w.keys())))))
print("Minimum Character Length {}".format(min(list(map(len,w.keys())))))
# Out:
# Number of Examples 9971
# Number of Unique Words 1687
# Maximum frequency 149
# Minimum frequency 2
# Maximum Character Length 18
# Minimum Character Length 4

# %%
w.most_common()
# Out:
# [('recycling', 149),
#  ('benefits', 136),
#  ('because', 98),
#  ('insurance', 93),
#  ('punishment', 80),
#  ('recycle', 78),
#  ('company', 66),
#  ('exactly', 65),
#  ('people', 60),
#  ('really', 59),
#  ('probably', 59),
#  ('newspapers', 57),
#  ('plastic', 57),
#  ('expensive', 56),
#  ('something', 56),
#  ('everything', 56),
#  ('things', 55),
#  ('problem', 54),
#  ('situation', 50),
#  ('important', 45),
#  ('problems', 43),
#  ('companies', 42),
#  ('testing', 41),
#  ('interesting', 40),
#  ('vacation', 39),
#  ('understand', 39),
#  ('retirement', 39),
#  ('somebody', 37),
#  ('actually', 36),
#  ('definitely', 36),
#  ('myself', 35),
#  ('recycled', 35),
#  ('especially', 34),
#  ('anything', 34),
#  ('person', 33),
#  ('absolutely', 33),
#  ('expenses', 33),
#  ('positive', 33),
#  ('system', 33),
#  ('security', 32),
#  ('program', 32),
#  ("that's", 31),
#  ('alcohol', 31),
#  ('college', 31),
#  ('aluminum', 30),
#  ('everybody', 30),
#  ('employees', 30),
#  ('plastics', 29),
#  ('bottles', 29),
#  ('before', 28),
#  ('dollars', 27),
#  ('sometimes', 27),
#  ('basically', 26),
#  ('budget', 26),
#  ('american', 26),
#  ('process', 26),
#  ('deterrent', 26),
#  ('family', 25),
#  ('organization', 25),
#  ('california', 25),
#  ('individual', 25),
#  ('employee', 24),
#  ('recently', 24),
#  ('someone', 24),
#  ('school', 24),
#  ('prescription', 24),
#  ('policy', 24),
#  ('dallas', 23),
#  ('toyota', 23),
#  ('thousand', 23),
#  ('whatever', 23),
#  ('newspaper', 23),
#  ('recyclable', 22),
#  ('penalty', 22),
#  ('privacy', 22),
#  ('themselves', 22),
#  ('benefit', 21),
#  ('environment', 21),
#  ('salary', 21),
#  ('particular', 21),
#  ('children', 21),
#  ('tested', 21),
#  ('personally', 21),
#  ('society', 20),
#  ('control', 20),
#  ('medical', 20),
#  ('crimes', 20),
#  ('community', 20),
#  ('concerned', 20),
#  ('anyway', 20),
#  ('garbage', 19),
#  ('circumstances', 19),
#  ('difference', 19),
#  ('places', 18),
#  ('education', 18),
#  ('comfortable', 18),
#  ('facilities', 17),
#  ('consider', 17),
#  ('question', 17),
#  ('yourself', 17),
#  ('percent', 17),
#  ('savings', 17),
#  ('anybody', 17),
#  ('around', 16),
#  ('convenient', 16),
#  ('corporation', 16),
#  ('husband', 16),
#  ('fifteen', 16),
#  ('driving', 16),
#  ('service', 16),
#  ('difficult', 15),
#  ('cadillac', 15),
#  ('computer', 15),
#  ('containers', 15),
#  ('management', 15),
#  ('government', 14),
#  ('papers', 14),
#  ('finances', 14),
#  ('financial', 14),
#  ('nineteen', 14),
#  ('participate', 14),
#  ('appeal', 14),
#  ('usually', 14),
#  ('decided', 14),
#  ('involved', 14),
#  ('pennsylvania', 14),
#  ('enough', 14),
#  ('reliable', 14),
#  ('surprised', 14),
#  ('mileage', 13),
#  ('accidents', 13),
#  ('experience', 13),
#  ('murder', 13),
#  ('styrofoam', 13),
#  ('industry', 13),
#  ('anymore', 13),
#  ('responsibility', 13),
#  ('repairs', 12),
#  ('budgeting', 12),
#  ('example', 12),
#  ('started', 12),
#  ('flexible', 12),
#  ('coverage', 12),
#  ('materials', 12),
#  ('certainly', 12),
#  ('obviously', 12),
#  ('smoking', 12),
#  ('acceptable', 12),
#  ('working', 12),
#  ('unfortunately', 12),
#  ('wonderful', 12),
#  ('university', 12),
#  ('business', 12),
#  ('magazines', 12),
#  ('prison', 12),
#  ('between', 11),
#  ('fantastic', 11),
#  ('knowledge', 11),
#  ('office', 11),
#  ('organized', 11),
#  ('everyone', 11),
#  ('perhaps', 11),
#  ('states', 11),
#  ('concern', 11),
#  ('always', 11),
#  ('possible', 11),
#  ('department', 11),
#  ('through', 11),
#  ('separate', 11),
#  ('hospital', 11),
#  ('extremely', 11),
#  ('excellent', 11),
#  ('cafeteria', 11),
#  ('mercedes', 11),
#  ('contract', 11),
#  ('itself', 11),
#  ('happens', 11),
#  ('marijuana', 11),
#  ('opportunity', 11),
#  ("there's", 11),
#  ('outside', 11),
#  ('capital', 10),
#  ('believe', 10),
#  ('retire', 10),
#  ('necessarily', 10),
#  ('completely', 10),
#  ('appeals', 10),
#  ('together', 10),
#  ('mandatory', 10),
#  ('available', 10),
#  ('change', 10),
#  ('incentive', 10),
#  ('behind', 10),
#  ('ridiculous', 10),
#  ('happened', 10),
#  ('massachusetts', 10),
#  ('rights', 10),
#  ('transportation', 9),
#  ('vehicle', 9),
#  ('specific', 9),
#  ('eventually', 9),
#  ('supervisor', 9),
#  ('against', 9),
#  ('reasonable', 9),
#  ('material', 9),
#  ('months', 9),
#  ('immediately', 9),
#  ('information', 9),
#  ('premeditated', 9),
#  ('terrible', 9),
#  ('expense', 9),
#  ('japanese', 9),
#  ('easier', 9),
#  ('corporations', 9),
#  ('remember', 9),
#  ('deposit', 9),
#  ('smokers', 9),
#  ('possibly', 9),
#  ('instance', 9),
#  ('dangerous', 9),
#  ('performance', 9),
#  ('trouble', 9),
#  ('employment', 9),
#  ('convicted', 9),
#  ('sixteen', 9),
#  ('consideration', 9),
#  ('percentage', 9),
#  ('instruments', 9),
#  ('deductible', 9),
#  ('considering', 9),
#  ('resources', 9),
#  ('conservative', 9),
#  ('random', 9),
#  ('medication', 9),
#  ('diapers', 9),
#  ('mistake', 9),
#  ('package', 9),
#  ('primarily', 8),
#  ('emergency', 8),
#  ('violation', 8),
#  ('realize', 8),
#  ('requirement', 8),
#  ('questions', 8),
#  ('comparable', 8),
#  ('executed', 8),
#  ('strange', 8),
#  ('investment', 8),
#  ('chemicals', 8),
#  ('economic', 8),
#  ('programs', 8),
#  ('totally', 8),
#  ('injection', 8),
#  ('paycheck', 8),
#  ('almost', 8),
#  ('certain', 8),
#  ('somewhere', 8),
#  ('imagine', 8),
#  ('enforced', 8),
#  ('effective', 8),
#  ('amazing', 8),
#  ('whenever', 8),
#  ('counseling', 8),
#  ('conscious', 8),
#  ('position', 8),
#  ('charge', 8),
#  ('supposedly', 8),
#  ('significant', 8),
#  ('future', 8),
#  ('spending', 8),
#  ('contractor', 8),
#  ('influence', 8),
#  ('originally', 8),
#  ('choice', 8),
#  ('military', 8),
#  ('country', 8),
#  ('finally', 8),
#  ('attitude', 8),
#  ('sentence', 8),
#  ('curbside', 8),
#  ('schools', 8),
#  ('situations', 8),
#  ('criminal', 8),
#  ('successful', 8),
#  ('incredible', 8),
#  ('nissan', 8),
#  ('employers', 8),
#  ('landfills', 8),
#  ('constantly', 7),
#  ('requirements', 7),
#  ('cocaine', 7),
#  ('starting', 7),
#  ('quickly', 7),
#  ('compost', 7),
#  ('parents', 7),
#  ('fortunate', 7),
#  ('products', 7),
#  ('considered', 7),
#  ('population', 7),
#  ('offenders', 7),
#  ('happening', 7),
#  ('institution', 7),
#  ('activities', 7),
#  ('apparently', 7),
#  ('little', 7),
#  ('rehabilitation', 7),
#  ('convertible', 7),
#  ('regular', 7),
#  ('specifically', 7),
#  ('landfill', 7),
#  ('income', 7),
#  ('product', 7),
#  ('anyone', 7),
#  ('automatically', 7),
#  ('conversion', 7),
#  ('contribute', 7),
#  ('employer', 7),
#  ('somehow', 7),
#  ('goodness', 7),
#  ('decide', 7),
#  ('project', 7),
#  ('careful', 7),
#  ('economy', 7),
#  ('public', 7),
#  ('automatic', 7),
#  ('suppose', 7),
#  ("haven't", 7),
#  ('reason', 7),
#  ('realistic', 7),
#  ('necessary', 7),
#  ('automobiles', 7),
#  ('windows', 7),
#  ('garage', 7),
#  ('entertainment', 7),
#  ('victim', 6),
#  ('protection', 6),
#  ('monthly', 6),
#  ('prices', 6),
#  ('substances', 6),
#  ('potential', 6),
#  ('impact', 6),
#  ('honestly', 6),
#  ('employed', 6),
#  ('beyond', 6),
#  ('pittsburgh', 6),
#  ('personal', 6),
#  ('personnel', 6),
#  ('overcrowded', 6),
#  ('technicality', 6),
#  ('insane', 6),
#  ('consumer', 6),
#  ('purchase', 6),
#  ('teachers', 6),
#  ('complicated', 6),
#  ('effect', 6),
#  ('minivan', 6),
#  ('without', 6),
#  ('saving', 6),
#  ('pilots', 6),
#  ('satisfied', 6),
#  ('warranty', 6),
#  ('complex', 6),
#  ('thinking', 6),
#  ('contribution', 6),
#  ('relatively', 6),
#  ('survive', 6),
#  ('taking', 6),
#  ('execute', 6),
#  ('christmas', 6),
#  ('florida', 6),
#  ('results', 6),
#  ('smaller', 6),
#  ('different', 6),
#  ('anywhere', 6),
#  ('practical', 6),
#  ('houses', 6),
#  ('called', 6),
#  ('chrysler', 6),
#  ('alcoholic', 6),
#  ('expected', 6),
#  ('younger', 6),
#  ('interested', 6),
#  ('packaging', 6),
#  ('schedule', 6),
#  ('otherwise', 6),
#  ('volkswagen', 6),
#  ("everybody's", 6),
#  ('equipment', 6),
#  ('fifties', 6),
#  ('established', 6),
#  ('account', 6),
#  ('collection', 6),
#  ('telephone', 6),
#  ('consulting', 6),
#  ('required', 6),
#  ('september', 6),
#  ('doctor', 6),
#  ('possibility', 6),
#  ('forever', 6),
#  ('criteria', 6),
#  ('besides', 6),
#  ('subject', 6),
#  ('opposed', 6),
#  ('another', 6),
#  ('chevrolet', 6),
#  ('fourteen', 6),
#  ('innocent', 6),
#  ('biodegradable', 6),
#  ('students', 6),
#  ('reliability', 6),
#  ('contact', 6),
#  ('computers', 6),
#  ('critical', 6),
#  ('unbelievable', 6),
#  ('opinion', 6),
#  ('happen', 6),
#  ('antilock', 6),
#  ('thought', 6),
#  ('building', 6),
#  ('serious', 6),
#  ('longer', 6),
#  ('conversation', 6),
#  ('individuals', 5),
#  ('pickup', 5),
#  ('agency', 5),
#  ('families', 5),
#  ('oldsmobile', 5),
#  ('exercise', 5),
#  ('clippings', 5),
#  ('typically', 5),
#  ('encourage', 5),
#  ('clothes', 5),
#  ('likelihood', 5),
#  ('impossible', 5),
#  ('criminals', 5),
#  ('somewhat', 5),
#  ("somebody's", 5),
#  ('reasons', 5),
#  ('twenty', 5),
#  ('unfair', 5),
#  ('dental', 5),
#  ('murders', 5),
#  ('should', 5),
#  ('seventy', 5),
#  ('controversy', 5),
#  ('rehabilitate', 5),
#  ('ourselves', 5),
#  ('murderers', 5),
#  ('research', 5),
#  ('combination', 5),
#  ('spreadsheet', 5),
#  ('properly', 5),
#  ('character', 5),
#  ('differently', 5),
#  ('seriously', 5),
#  ('travel', 5),
#  ('categories', 5),
#  ('illegal', 5),
#  ('outrageous', 5),
#  ('medicine', 5),
#  ('practice', 5),
#  ('industries', 5),
#  ('investments', 5),
#  ('expect', 5),
#  ('accounts', 5),
#  ('mistakes', 5),
#  ('vacations', 5),
#  ('survey', 5),
#  ('stores', 5),
#  ('taurus', 5),
#  ('options', 5),
#  ('sometime', 5),
#  ('consultant', 5),
#  ('responsible', 5),
#  ('solution', 5),
#  ('utilities', 5),
#  ('finding', 5),
#  ('enjoyable', 5),
#  ('changes', 5),
#  ('frivolous', 5),
#  ('property', 5),
#  ('checkbook', 5),
#  ('becoming', 5),
#  ('conditions', 5),
#  ('prisons', 5),
#  ('hospitalization', 5),
#  ('substance', 5),
#  ('envelope', 5),
#  ('engineers', 5),
#  ('nowadays', 5),
#  ('substitute', 5),
#  ('participating', 5),
#  ('fairly', 5),
#  ('category', 5),
#  ('motivation', 5),
#  ('county', 5),
#  ('chance', 5),
#  ('invasion', 5),
#  ('groceries', 5),
#  ('cardboard', 5),
#  ('substantial', 5),
#  ('interest', 5),
#  ('reinstated', 5),
#  ('cadillacs', 5),
#  ('corolla', 5),
#  ('streets', 5),
#  ('hospitals', 5),
#  ('church', 5),
#  ('require', 5),
#  ('facility', 5),
#  ('suspicion', 5),
#  ('participated', 5),
#  ('gallon', 5),
#  ('depends', 5),
#  ('styling', 5),
#  ('selling', 5),
#  ('accident', 5),
#  ('positions', 5),
#  ('traveling', 5),
#  ('minivans', 5),
#  ('aspect', 5),
#  ('parole', 5),
#  ('separated', 5),
#  ('decision', 5),
#  ('luxury', 5),
#  ('pressure', 5),
#  ('tercel', 5),
#  ('protecting', 5),
#  ('mostly', 5),
#  ('anyways', 5),
#  ('transmission', 5),
#  ('arlington', 5),
#  ('overcrowding', 5),
#  ('within', 5),
#  ('afford', 5),
#  ('statistics', 5),
#  ('course', 5),
#  ('considerations', 5),
#  ('choices', 5),
#  ('legislatures', 5),
#  ('engineer', 5),
#  ('decompose', 5),
#  ('unexpected', 5),
#  ('safety', 5),
#  ('automobile', 5),
#  ('guilty', 5),
#  ('fortunately', 4),
#  ('designed', 4),
#  ('justified', 4),
#  ('suspect', 4),
#  ('dealership', 4),
#  ('dismissal', 4),
#  ('beginning', 4),
#  ('forties', 4),
#  ('whatsoever', 4),
#  ('washington', 4),
#  ('purchases', 4),
#  ('plymouth', 4),
#  ('consensus', 4),
#  ('accord', 4),
#  ('positives', 4),
#  ('someplace', 4),
#  ('elective', 4),
#  ('unfortunate', 4),
#  ('workers', 4),
#  ('atlanta', 4),
#  ('excuse', 4),
#  ('planning', 4),
#  ("you're", 4),
#  ('changed', 4),
#  ('afraid', 4),
#  ('backseat', 4),
#  ('planned', 4),
#  ('conversations', 4),
#  ('professions', 4),
#  ('operation', 4),
#  ('extreme', 4),
#  ('better', 4),
#  ('justice', 4),
#  ('monday', 4),
#  ('strongly', 4),
#  ('instances', 4),
#  ('already', 4),
#  ('legislation', 4),
#  ('naturally', 4),
#  ('married', 4),
#  ('general', 4),
#  ('lawyers', 4),
#  ('colors', 4),
#  ('sixties', 4),
#  ('checks', 4),
#  ('explorer', 4),
#  ('productivity', 4),
#  ('scholarship', 4),
#  ('applied', 4),
#  ('drivers', 4),
#  ('manufacturers', 4),
#  ('friends', 4),
#  ('having', 4),
#  ('covered', 4),
#  ('crowded', 4),
#  ('recyclables', 4),
#  ('manpower', 4),
#  ('controllers', 4),
#  ('mentioned', 4),
#  ('conditioning', 4),
#  ('worthwhile', 4),
#  ('manager', 4),
#  ('genuine', 4),
#  ('kitchen', 4),
#  ('accepted', 4),
#  ('designated', 4),
#  ('plants', 4),
#  ('graduated', 4),
#  ('calculator', 4),
#  ('discuss', 4),
#  ('become', 4),
#  ('violence', 4),
#  ('seventies', 4),
#  ('nothing', 4),
#  ('supported', 4),
#  ('features', 4),
#  ('making', 4),
#  ('caught', 4),
#  ('generation', 4),
#  ('buying', 4),
#  ('literally', 4),
#  ('contractors', 4),
#  ('trying', 4),
#  ('majority', 4),
#  ('further', 4),
#  ('hopefully', 4),
#  ('objectives', 4),
#  ('federal', 4),
#  ('provide', 4),
#  ('dissatisfied', 4),
#  ('international', 4),
#  ('cartons', 4),
#  ('weekends', 4),
#  ('particularly', 4),
#  ('continuing', 4),
#  ('dependable', 4),
#  ('killed', 4),
#  ('punishments', 4),
#  ("mcdonald's", 4),
#  ('single', 4),
#  ('abused', 4),
#  ('however', 4),
#  ('supposed', 4),
#  ('experiment', 4),
#  ('passenger', 4),
#  ('towards', 4),
#  ('numbers', 4),
#  ('except', 4),
#  ('judicial', 4),
#  ('sharing', 4),
#  ('damage', 4),
#  ('tuition', 4),
#  ('station', 4),
#  ('communities', 4),
#  ('retired', 4),
#  ('athletes', 4),
#  ('recruiters', 4),
#  ('paying', 4),
#  ('occasional', 4),
#  ('standard', 4),
#  ('versus', 4),
#  ('surprises', 4),
#  ('currently', 4),
#  ('budgeted', 4),
#  ('indirectly', 4),
#  ('terminate', 4),
#  ('valuable', 4),
#  ('container', 4),
#  ('authorities', 4),
#  ('intent', 4),
#  ('reusable', 4),
#  ('structure', 4),
#  ('reimbursed', 4),
#  ('wisconsin', 4),
#  ('across', 4),
#  ('popular', 4),
#  ('screening', 4),
#  ('environmental', 4),
#  ('rehabilitated', 4),
#  ('consistent', 4),
#  ('developed', 4),
#  ('guidelines', 4),
#  ('deductions', 4),
#  ('standards', 4),
#  ('financially', 4),
#  ('friend', 4),
#  ('businesses', 4),
#  ('unemployment', 4),
#  ('managers', 4),
#  ('policies', 4),
#  ('disposable', 4),
#  ('holidays', 4),
#  ('assistance', 4),
#  ('vested', 4),
#  ('ignorant', 4),
#  ('introduced', 4),
#  ('medications', 4),
#  ('quality', 4),
#  ('machinery', 4),
#  ('driven', 4),
#  ('occasionally', 4),
#  ('penalties', 4),
#  ('fiancee', 4),
#  ('obvious', 4),
#  ('tennessee', 4),
#  ('tremendous', 4),
#  ('downtown', 4),
#  ('standpoint', 4),
#  ('enforcement', 4),
#  ('probation', 4),
#  ('concerns', 4),
#  ('providing', 4),
#  ('dealers', 4),
#  ('departments', 4),
#  ('secretary', 4),
#  ('apartment', 4),
#  ('extensive', 4),
#  ('americans', 4),
#  ('voyager', 4),
#  ('feeling', 4),
#  ('frequently', 4),
#  ('brakes', 4),
#  ('profit', 4),
#  ('voluntary', 4),
#  ('determine', 4),
#  ('prohibition', 4),
#  ('limited', 4),
#  ('cooperation', 3),
#  ('rochester', 3),
#  ('dispose', 3),
#  ('courts', 3),
#  ('teenagers', 3),
#  ('dumpsters', 3),
#  ('comfort', 3),
#  ('offices', 3),
#  ('saturdays', 3),
#  ("they're", 3),
#  ('herself', 3),
#  ('reward', 3),
#  ('reluctant', 3),
#  ('exciting', 3),
#  ('cancel', 3),
#  ('maximum', 3),
#  ('hundreds', 3),
#  ('payment', 3),
#  ('marvelous', 3),
#  ('pretty', 3),
#  ('encourages', 3),
#  ('vehicles', 3),
#  ('statement', 3),
#  ('president', 3),
#  ('rehabilitating', 3),
#  ('prefer', 3),
#  ('richardson', 3),
#  ('prisoners', 3),
#  ('stringent', 3),
#  ('interface', 3),
#  ('preference', 3),
#  ('premium', 3),
#  ('towncar', 3),
#  ('remorse', 3),
#  ('generate', 3),
#  ('sudden', 3),
#  ('apples', 3),
#  ('correct', 3),
#  ('february', 3),
#  ('recreational', 3),
#  ('regularly', 3),
#  ('entire', 3),
#  ('specialized', 3),
#  ('chicago', 3),
#  ('design', 3),
#  ('constant', 3),
#  ('status', 3),
#  ('knowledgeable', 3),
#  ('separating', 3),
#  ('respect', 3),
#  ('circumstance', 3),
#  ('allowance', 3),
#  ('outstanding', 3),
#  ('retest', 3),
#  ('manson', 3),
#  ('systems', 3),
#  ('whether', 3),
#  ('kidding', 3),
#  ('comfortably', 3),
#  ('experimenting', 3),
#  ('negative', 3),
#  ('commitment', 3),
#  ('restaurant', 3),
#  ('sentencing', 3),
#  ('reminds', 3),
#  ('defense', 3),
#  ('maintenance', 3),
#  ('participation', 3),
#  ('figured', 3),
#  ('shopping', 3),
#  ('eliminate', 3),
#  ('access', 3),
#  ('francisco', 3),
#  ('association', 3),
#  ('polygraph', 3),
#  ("person's", 3),
#  ('arrested', 3),
#  ('celica', 3),
#  ('reduce', 3),
#  ("wasn't", 3),
#  ('extended', 3),
#  ('central', 3),
#  ('electricity', 3),
#  ('metroplex', 3),
#  ('controlled', 3),
#  ('importance', 3),
#  ('metropolitan', 3),
#  ('dependents', 3),
#  ('normal', 3),
#  ('cannot', 3),
#  ('{unsmashed}', 3),
#  ('summer', 3),
#  ('construction', 3),
#  ('string', 3),
#  ('qualified', 3),
#  ('allotted', 3),
#  ('batteries', 3),
#  ('explain', 3),
#  ('absolute', 3),
#  ('background', 3),
#  ('retarded', 3),
#  ('ecologically', 3),
#  ('accurate', 3),
#  ('student', 3),
#  ('deductibles', 3),
#  ('competitive', 3),
#  ('support', 3),
#  ('accept', 3),
#  ('finance', 3),
#  ('countries', 3),
#  ('paroled', 3),
#  ('likewise', 3),
#  ('existence', 3),
#  ('dekalb', 3),
#  ('normally', 3),
#  ('disappointed', 3),
#  ('everytime', 3),
#  ('discipline', 3),
#  ('interfere', 3),
#  ('powerful', 3),
#  ('stereo', 3),
#  ('accused', 3),
#  ('handling', 3),
#  ('compare', 3),
#  ('entitled', 3),
#  ('victimized', 3),
#  ('complete', 3),
#  ('tremendously', 3),
#  ('severe', 3),
#  ('activity', 3),
#  ('hiring', 3),
#  ('allowances', 3),
#  ('facing', 3),
#  ('behavior', 3),
#  ('eighteen', 3),
#  ('teacher', 3),
#  ('several', 3),
#  ('pontiac', 3),
#  ('motivated', 3),
#  ('glasses', 3),
#  ('socially', 3),
#  ('advance', 3),
#  ('purchased', 3),
#  ('sporty', 3),
#  ('individually', 3),
#  ('limitations', 3),
#  ('interview', 3),
#  ('effects', 3),
#  ('advantage', 3),
#  ('scholarships', 3),
#  ('behave', 3),
#  ('managed', 3),
#  ('losing', 3),
#  ('kidnapping', 3),
#  ('carefully', 3),
#  ('dismissed', 3),
#  ('publicity', 3),
#  ('opinions', 3),
#  ('credit', 3),
#  ('records', 3),
#  ('natural', 3),
#  ('volunteer', 3),
#  ('ground', 3),
#  ('officers', 3),
#  ('leavenworth', 3),
#  ('suggested', 3),
#  ('institute', 3),
#  ('economically', 3),
#  ('qualify', 3),
#  ('handle', 3),
#  ('minimum', 3),
#  ('comparison', 3),
#  ('milwaukee', 3),
#  ('decisions', 3),
#  ('scouts', 3),
#  ('factory', 3),
#  ('capability', 3),
#  ('beforehand', 3),
#  ('reaction', 3),
#  ('appropriate', 3),
#  ('lifestyle', 3),
#  ('market', 3),
#  ('serviceable', 3),
#  ('heinous', 3),
#  ('european', 3),
#  ('nonsmoker', 3),
#  ('optical', 3),
#  ('physical', 3),
#  ('gasoline', 3),
#  ('justify', 3),
#  ('legislate', 3),
#  ('minimize', 3),
#  ('direction', 3),
#  ('minnesota', 3),
#  ('reports', 3),
#  ('extravagant', 3),
#  ('hyundai', 3),
#  ('closely', 3),
#  ('vegetables', 3),
#  ('traction', 3),
#  ('neighborhood', 3),
#  ('sample', 3),
#  ('civilized', 3),
#  ('manufacturing', 3),
#  ('factor', 3),
#  ('alternative', 3),
#  ('orthodontic', 3),
#  ('communicate', 3),
#  ('distance', 3),
#  ('institutions', 3),
#  ('bought', 3),
#  ('okay', 3),
#  ('balance', 3),
#  ('november', 3),
#  ('projects', 3),
#  ('america', 3),
#  ('disease', 3),
#  ('explained', 3),
#  ('thirteen', 3),
#  ('authorized', 3),
#  ('cigarettes', 3),
#  ('keeping', 3),
#  ('national', 3),
#  ('return', 3),
#  ('previous', 3),
#  ('electronic', 3),
#  ('ability', 3),
#  ('steroids', 3),
#  ('largest', 3),
#  ('applications', 3),
#  ('prevalent', 3),
#  ('surprisingly', 3),
#  ('machines', 3),
#  ('challenge', 3),
#  ('telecommunications', 3),
#  ('protected', 3),
#  ('magazine', 3),
#  ('differences', 3),
#  ('amphetamines', 3),
#  ('samples', 3),
#  ('refuse', 3),
#  ('citizens', 3),
#  ('oldsmobiles', 3),
#  ('nurses', 3),
#  ('january', 3),
#  ('common', 3),
#  ('witnesses', 3),
#  ('inside', 3),
#  ('giving', 3),
#  ('liberal', 3),
#  ('storage', 3),
#  ('dedicated', 3),
#  ('funding', 3),
#  ('bigger', 3),
#  ('virginia', 3),
#  ('special', 3),
#  ('exclusively', 3),
#  ('cheaper', 3),
#  ('temporary', 3),
#  ('budgets', 3),
#  ('consequences', 3),
#  ('father', 3),
#  ('plywood', 3),
#  ('deciding', 3),
#  ('option', 3),
#  ('changing', 3),
#  ('authority', 3),
#  ('checkbooks', 3),
#  ...]

# %%
w_c = Counter(w.values())
w_c.most_common()
# Out:
# [(2, 626),
#  (3, 329),
#  (4, 187),
#  (5, 124),
#  (6, 88),
#  (8, 50),
#  (7, 46),
#  (9, 40),
#  (11, 26),
#  (12, 18),
#  (10, 16),
#  (14, 14),
#  (13, 8),
#  (20, 7),
#  (17, 7),
#  (21, 7),
#  (16, 7),
#  (24, 6),
#  (33, 5),
#  (26, 5),
#  (15, 5),
#  (23, 5),
#  (22, 4),
#  (25, 4),
#  (39, 3),
#  (56, 3),
#  (30, 3),
#  (31, 3),
#  (18, 3),
#  (19, 3),
#  (29, 2),
#  (59, 2),
#  (34, 2),
#  (57, 2),
#  (32, 2),
#  (36, 2),
#  (35, 2),
#  (27, 2),
#  (80, 1),
#  (98, 1),
#  (149, 1),
#  (93, 1),
#  (66, 1),
#  (136, 1),
#  (65, 1),
#  (55, 1),
#  (37, 1),
#  (78, 1),
#  (60, 1),
#  (28, 1),
#  (50, 1),
#  (41, 1),
#  (54, 1),
#  (43, 1),
#  (42, 1),
#  (45, 1),
#  (40, 1)]

# %%
plt.ylabel("Frequenciy of frequency of words")
plt.xlabel("Frequency of words")
plt.hist(w.values())
# Out:
# (array([1584.,   62.,   22.,   11.,    2.,    2.,    2.,    0.,    0.,
#            2.]),
#  array([  2. ,  16.7,  31.4,  46.1,  60.8,  75.5,  90.2, 104.9, 119.6,
#         134.3, 149. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Stats of AMI Dataset

# %%
snr = np.Inf
num_examples = np.Inf
dh = DataHelper(snr,num_examples)
dh.load_data(char_threshold = 4, frequency_bounds = (0,np.Inf))
dh.process_data()
c,word_to_num,num_to_word = dh.generate_key_dicts()

inputs,labels = dh.give_inputs_and_labels()
# Out:
# Length before filtering on char length 169383
# Length after filtering on char length 114148
# Finished Loading the Data, 114148 examples
# Number of Unique words  9499

# %%
c = Counter(dh.keys)

# %%
c = Counter(dh.keys)
print("Number of Examples {}".format(len(dh.keys)))
print("Number of Unique Words {}".format(len(c.keys())))
print("Maximum frequency {}".format(max(c.values())))
print("Minimum frequency {}".format(min(c.values())))
print("Maximum Character Length {}".format(max(list(map(len,c.keys())))))
print("Minimum Character Length {}".format(min(list(map(len,c.keys())))))
# Out:
# Number of Examples 114148
# Number of Unique Words 9499
# Maximum frequency 7049
# Minimum frequency 1
# Maximum Character Length 20
# Minimum Character Length 4

# %%
c.most_common()
words,freq = zip(*c.most_common())

# %%
fig, axs = plt.subplots(2, 2, figsize=(10,10))
fig.suptitle('Frequency Histogram')
axs[0, 0].hist(freq[:10])
axs[0, 0].set_title('Top 10 words')
axs[0, 1].hist(freq[10:100])
axs[0, 1].set_title('Top 10-100 words')
axs[1, 0].hist(freq[100:500])
axs[1, 0].set_title('Top 100-500 words')
axs[1, 1].hist(freq[500:1000])
axs[1, 1].set_title('Top 500-1000 words')

for ax in axs.flat:
    ax.set(xlabel='Frequency', ylabel='Number of Words')

# %%
plt.title('Frequency Histogram')
plt.hist(freq[1000:5000])
plt.title('Top 1000-5000 words')
plt.xlabel('Frequency')
plt.ylabel('Number of Words')
# Out:
# Text(0, 0.5, 'Number of Words')

# %%
plt.xlabel("Freq of words")
plt.ylabel("Freq of freq of words")
plt.hist(c.values(),range = (0,150))
# Out:
# (array([9200.,  731.,  306.,  181.,  122.,   80.,   60.,   46.,   44.,
#           46.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <a list of 10 Patch objects>)

# %%
x_set = set(w.keys())
y_set = set(c.keys())

print(len(x_set.intersection(y_set)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4038fc04080c> in <module>
# ----> 1 x_set = set(w.keys())
#       2 y_set = set(c.keys())
#       3
#       4 print(len(x_set.intersection(y_set)))
#
# NameError: name 'w' is not defined

# %% [markdown]
# Rough
